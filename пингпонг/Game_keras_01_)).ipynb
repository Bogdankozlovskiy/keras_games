# %%
from __future__ import division,print_function
import collections
import numpy as np
import pygame
import random
import os
from time import sleep

# %%
class MyWrappedGame(object):
    def __init__(self):
        #os.environ["SDL_VIDEODRIVER"] = "dummy"
        pygame.init()
        self.COLOR_WHITE = (255,255,255)
        self.COLOR_BLACK = (0,0,0)
        self.GAME_WIDTH = 400
        self.GAME_HEIGHT = 400
        self.BALL_WIDTH = 20
        self.BALL_HEIGHT = 20
        self.PADDLE_WIDTH = 50
        self.PADDLE_HEIGHT = 10
        self.GAME_FLOOR = 350
        self.GAME_CEILING = 10
        self.BALL_VELOCITY = 10
        self.PADDLE_VELOCITY = 20
        self.FONT_SIZE = 30
        self.MAX_TRIES_PER_GAME = 1
        self.CUSTOM_EVENT = pygame.USEREVENT + 1
        self.font = pygame.font.SysFont("Comic Sans MS",self.FONT_SIZE)
    
    def reset(self):
        self.frames = collections.deque(maxlen=4)
        self.game_over = False
        self.paddle_x = self.GAME_WIDTH // 2
        self.game_score =  0
        self.reward = 0
        self.ball_x = random.randint(0, self.GAME_WIDTH)
        self.ball_y = self.GAME_CEILING
        self.num_tries = 0
        self.screen = pygame.display.set_mode((self.GAME_WIDTH,self.GAME_HEIGHT))
        self.clock = pygame.time.Clock()
    
    def step(self,action):
        pygame.event.pump()
        if action == 0:
            self.paddle_x -= self.PADDLE_VELOCITY
            if self.paddle_x < 0:
                self.paddle_x = self.PADDLE_VELOCITY
        elif action == 2:
            self.paddle_x += self.PADDLE_VELOCITY
            if self.paddle_x > self.GAME_WIDTH - self.PADDLE_WIDTH:
                self.paddle_x = self.GAME_WIDTH - self.PADDLE_WIDTH -self.PADDLE_VELOCITY
        else:
            pass
        self.screen.fill(self.COLOR_BLACK)
        score_text = self.font.render("Score:{:d}/{:d},Ball:{:d}".format(self.game_score,self.MAX_TRIES_PER_GAME,self.num_tries),True,self.COLOR_WHITE)
        self.screen.blit(score_text,((self.GAME_WIDTH - score_text.get_width()) // 2,(self.GAME_FLOOR + self.FONT_SIZE // 2)))
        self.ball_y += self.BALL_VELOCITY
        ball = pygame.draw.rect(self.screen, self.COLOR_WHITE,pygame.Rect(self.ball_x,self.ball_y,self.BALL_WIDTH,self.BALL_HEIGHT))
        paddle = pygame.draw.rect(self.screen, self.COLOR_WHITE,pygame.Rect(self.paddle_x,self.GAME_FLOOR,self.PADDLE_WIDTH,self.PADDLE_HEIGHT))
        self.reward = 0
        if self.ball_y >= self.GAME_FLOOR - self.BALL_WIDTH // 2:
            if ball.colliderect(paddle):
                self.reward = 1
            else:
                self.reward = -1
        
            self.game_score += self.reward
            self.ball_x = random.randint(0, self.GAME_WIDTH)
            self.ball_y = self.GAME_CEILING
            self.num_tries += 1
        
        pygame.display.flip()
        
        self.frames.append(pygame.surfarray.array2d(self.screen))
        
        if self.num_tries >= self.MAX_TRIES_PER_GAME:
            self.game_over = True
        
        self.clock.tick(30)
        return np.array(list(self.frames)),self.reward, self.game_over

# %%
from keras.models import Sequential
from keras.layers.core import Activation,Dense,Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
from scipy.misc.pilutil import imresize 
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
def preprocess_images(images):
    if images.shape[0] < 4:
        x_t = images[0]
        x_t = imresize(x_t,(80,80))
        x_t = x_t.astype("float")
        x_t /= 255.0
        s_t = np.stack((x_t,x_t,x_t,x_t),axis=2)
    else:
        xt_list=[]
        for i in range(images.shape[0]):
            x_t = imresize(images[i],(80,80))
            x_t = x_t.astype("float")
            x_t /= 255.0
            xt_list.append(x_t)
        s_t = np.stack((xt_list[0],xt_list[1],xt_list[2],xt_list[3]),axis=2)
    s_t = np.expand_dims(s_t,axis=0)
    return s_t

def get_next_batch(experince,model,num_actions,gamma,batch_size):
    batch_indices = np.random.randint(low=0,high=len(experince),size=batch_size)
    batch = [experince[i] for i in batch_indices]
    X = np.zeros((batch_size,80,80,4))
    Y = np.zeros((batch_size,num_actions))
    for i in range(len(batch)):
        s_t,a_t,r_t,s_tp1,game_over = batch[i]
        X[i] = s_t
        Y[i] = model.predict(s_t)[0]
        Q_sa = np.max(model.predict(s_tp1)[0])
        if game_over:
            Y[i,a_t] = r_t
        else:
            Y[i,a_t] = r_t + gamma * Q_sa
    return X,Y

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=8, strides=4,kernel_initializer="normal",padding="same",input_shape=(80,80,4)))
model.add(Activation("relu"))
model.add(Conv2D(64, kernel_size=4, strides=2,kernel_initializer="normal",padding="same"))
model.add(Activation("relu"))
model.add(Conv2D(64, kernel_size=3, strides=1,kernel_initializer="normal",padding="same"))
model.add(Activation("relu"))
model.add(Flatten())
model.add(Dense(512,kernel_initializer="normal"))
model.add(Activation("relu"))
model.add(Dense(3,kernel_initializer="normal"))
model.compile(optimizer=Adam(lr=1e-6),loss="mse")

# %%
NUM_ACTIONS = 3
GAMMA = 0.99
INITIAL_EPSILON = 0.1
FINAL_EPSILON = 0.0001
MEMORY_SIZE = 7000
NUM_EPOCHS_OBSERVE = 100
NUM_EPOCHS_TRAIN = 2000

BATCH_SIZE = 32
NUM_EPOCHS = NUM_EPOCHS_OBSERVE + NUM_EPOCHS_TRAIN

game = MyWrappedGame()
experince = collections.deque(maxlen=MEMORY_SIZE)

num_games,num_wins=0,0
epsilon = INITIAL_EPSILON

# %%
for e in range(NUM_EPOCHS):
    game.reset()
    loss = 0.0
    a_0=1
    x_t,r_0,game_over = game.step(a_0)
    s_t = preprocess_image(x_t)
    game_over = False
    while not game_over:
        s_tml = s_t
        #следующее действие
        if e <= NUM_EPOCHS_OBSERVE:
            a_t = np.random.randint(low=0,high=NUM_ACTIONS,size=1)[0]
        else:
            if np.random.rand() <= epsilon:
                a_t = np.random.randint(low=0,high=NUM_ACTIONS,size=1)[0]
            else:
                q = model.predict(s_t)[0]
                a_t = np.argmax(q)
        # применить действие к игре
        x_t, r_t, game_over=game.step(a_t)
        s_t = preprocess_images(x_t)
        #если вознагрождение положительно, увеличить num_wins
        if r_t == 1:
            num_wins += 1
        #сохраним опыт
        experince.append((s_tml, a_t, r_t, s_t, game_over))
        if e > NUM_EPOCHS_OBSERVE:
            X,Y = get_next_batch(experince,model,NUM_ACTIONS,GAMMA,BATCH_SIZE)
            loss += model.train_on_batch(X,Y)
            if epsilon > FINAL_EPSILON:
                epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / NUM_EPOCHS
    print("Epoch {:04d}/{:d} | Loss {:.5f} | Win Count {:d}".format(e + 1,NUM_EPOCHS,loss,num_wins))
# Out:
# Epoch 0001/2100 | Loss 0.00000 | Win Count 0
# Epoch 0002/2100 | Loss 0.00000 | Win Count 0
# Epoch 0003/2100 | Loss 0.00000 | Win Count 0
# Epoch 0004/2100 | Loss 0.00000 | Win Count 0
# Epoch 0005/2100 | Loss 0.00000 | Win Count 1
# Epoch 0006/2100 | Loss 0.00000 | Win Count 1
# Epoch 0007/2100 | Loss 0.00000 | Win Count 1
# Epoch 0008/2100 | Loss 0.00000 | Win Count 1
# Epoch 0009/2100 | Loss 0.00000 | Win Count 1
# Epoch 0010/2100 | Loss 0.00000 | Win Count 1
# Epoch 0011/2100 | Loss 0.00000 | Win Count 2
# Epoch 0012/2100 | Loss 0.00000 | Win Count 2
# Epoch 0013/2100 | Loss 0.00000 | Win Count 2
# Epoch 0014/2100 | Loss 0.00000 | Win Count 2
# Epoch 0015/2100 | Loss 0.00000 | Win Count 2
# Epoch 0016/2100 | Loss 0.00000 | Win Count 3
# Epoch 0017/2100 | Loss 0.00000 | Win Count 3
# Epoch 0018/2100 | Loss 0.00000 | Win Count 4
# Epoch 0019/2100 | Loss 0.00000 | Win Count 4
# Epoch 0020/2100 | Loss 0.00000 | Win Count 4
# Epoch 0021/2100 | Loss 0.00000 | Win Count 4
# Epoch 0022/2100 | Loss 0.00000 | Win Count 4
# Epoch 0023/2100 | Loss 0.00000 | Win Count 5
# Epoch 0024/2100 | Loss 0.00000 | Win Count 5
# Epoch 0025/2100 | Loss 0.00000 | Win Count 5
# Epoch 0026/2100 | Loss 0.00000 | Win Count 6
# Epoch 0027/2100 | Loss 0.00000 | Win Count 6
# Epoch 0028/2100 | Loss 0.00000 | Win Count 6
# Epoch 0029/2100 | Loss 0.00000 | Win Count 6
# Epoch 0030/2100 | Loss 0.00000 | Win Count 6
# Epoch 0031/2100 | Loss 0.00000 | Win Count 6
# Epoch 0032/2100 | Loss 0.00000 | Win Count 6
# Epoch 0033/2100 | Loss 0.00000 | Win Count 6
# Epoch 0034/2100 | Loss 0.00000 | Win Count 6
# Epoch 0035/2100 | Loss 0.00000 | Win Count 6
# Epoch 0036/2100 | Loss 0.00000 | Win Count 6
# Epoch 0037/2100 | Loss 0.00000 | Win Count 6
# Epoch 0038/2100 | Loss 0.00000 | Win Count 7
# Epoch 0039/2100 | Loss 0.00000 | Win Count 7
# Epoch 0040/2100 | Loss 0.00000 | Win Count 7
# Epoch 0041/2100 | Loss 0.00000 | Win Count 7
# Epoch 0042/2100 | Loss 0.00000 | Win Count 7
# Epoch 0043/2100 | Loss 0.00000 | Win Count 7
# Epoch 0044/2100 | Loss 0.00000 | Win Count 7
# Epoch 0045/2100 | Loss 0.00000 | Win Count 7
# Epoch 0046/2100 | Loss 0.00000 | Win Count 7
# Epoch 0047/2100 | Loss 0.00000 | Win Count 7
# Epoch 0048/2100 | Loss 0.00000 | Win Count 7
# Epoch 0049/2100 | Loss 0.00000 | Win Count 7
# Epoch 0050/2100 | Loss 0.00000 | Win Count 7
# Epoch 0051/2100 | Loss 0.00000 | Win Count 7
# Epoch 0052/2100 | Loss 0.00000 | Win Count 7
# Epoch 0053/2100 | Loss 0.00000 | Win Count 7
# Epoch 0054/2100 | Loss 0.00000 | Win Count 8
# Epoch 0055/2100 | Loss 0.00000 | Win Count 8
# Epoch 0056/2100 | Loss 0.00000 | Win Count 8
# Epoch 0057/2100 | Loss 0.00000 | Win Count 8
# Epoch 0058/2100 | Loss 0.00000 | Win Count 9
# Epoch 0059/2100 | Loss 0.00000 | Win Count 9
# Epoch 0060/2100 | Loss 0.00000 | Win Count 9
# Epoch 0061/2100 | Loss 0.00000 | Win Count 9
# Epoch 0062/2100 | Loss 0.00000 | Win Count 9
# Epoch 0063/2100 | Loss 0.00000 | Win Count 10
# Epoch 0064/2100 | Loss 0.00000 | Win Count 10
# Epoch 0065/2100 | Loss 0.00000 | Win Count 10
# Epoch 0066/2100 | Loss 0.00000 | Win Count 10
# Epoch 0067/2100 | Loss 0.00000 | Win Count 10
# Epoch 0068/2100 | Loss 0.00000 | Win Count 10
# Epoch 0069/2100 | Loss 0.00000 | Win Count 11
# Epoch 0070/2100 | Loss 0.00000 | Win Count 11
# Epoch 0071/2100 | Loss 0.00000 | Win Count 11
# Epoch 0072/2100 | Loss 0.00000 | Win Count 11
# Epoch 0073/2100 | Loss 0.00000 | Win Count 12
# Epoch 0074/2100 | Loss 0.00000 | Win Count 12
# Epoch 0075/2100 | Loss 0.00000 | Win Count 12
# Epoch 0076/2100 | Loss 0.00000 | Win Count 12
# Epoch 0077/2100 | Loss 0.00000 | Win Count 12
# Epoch 0078/2100 | Loss 0.00000 | Win Count 12
# Epoch 0079/2100 | Loss 0.00000 | Win Count 12
# Epoch 0080/2100 | Loss 0.00000 | Win Count 12
# Epoch 0081/2100 | Loss 0.00000 | Win Count 12
# Epoch 0082/2100 | Loss 0.00000 | Win Count 12
# Epoch 0083/2100 | Loss 0.00000 | Win Count 13
# Epoch 0084/2100 | Loss 0.00000 | Win Count 14
# Epoch 0085/2100 | Loss 0.00000 | Win Count 14
# Epoch 0086/2100 | Loss 0.00000 | Win Count 15
# Epoch 0087/2100 | Loss 0.00000 | Win Count 15
# Epoch 0088/2100 | Loss 0.00000 | Win Count 15
# Epoch 0089/2100 | Loss 0.00000 | Win Count 15
# Epoch 0090/2100 | Loss 0.00000 | Win Count 15
# Epoch 0091/2100 | Loss 0.00000 | Win Count 15
# Epoch 0092/2100 | Loss 0.00000 | Win Count 15
# Epoch 0093/2100 | Loss 0.00000 | Win Count 15
# Epoch 0094/2100 | Loss 0.00000 | Win Count 15
# Epoch 0095/2100 | Loss 0.00000 | Win Count 16
# Epoch 0096/2100 | Loss 0.00000 | Win Count 16
# Epoch 0097/2100 | Loss 0.00000 | Win Count 16
# Epoch 0098/2100 | Loss 0.00000 | Win Count 16
# Epoch 0099/2100 | Loss 0.00000 | Win Count 16
# Epoch 0100/2100 | Loss 0.00000 | Win Count 16
# Epoch 0101/2100 | Loss 0.00000 | Win Count 16
# Epoch 0102/2100 | Loss 1.50987 | Win Count 16
# Epoch 0103/2100 | Loss 1.60078 | Win Count 16
# Epoch 0104/2100 | Loss 1.82147 | Win Count 17
# Epoch 0105/2100 | Loss 1.85488 | Win Count 17
# Epoch 0106/2100 | Loss 2.66459 | Win Count 18
# Epoch 0107/2100 | Loss 1.68574 | Win Count 18
# Epoch 0108/2100 | Loss 2.60076 | Win Count 18
# Epoch 0109/2100 | Loss 3.25572 | Win Count 18
# Epoch 0110/2100 | Loss 2.60706 | Win Count 19
# Epoch 0111/2100 | Loss 2.42479 | Win Count 19
# Epoch 0112/2100 | Loss 2.02584 | Win Count 19
# Epoch 0113/2100 | Loss 3.05899 | Win Count 19
# Epoch 0114/2100 | Loss 3.34523 | Win Count 19
# Epoch 0115/2100 | Loss 2.74112 | Win Count 19
# Epoch 0116/2100 | Loss 2.59616 | Win Count 20
# Epoch 0117/2100 | Loss 4.34151 | Win Count 20
# Epoch 0118/2100 | Loss 2.84112 | Win Count 21
# Epoch 0119/2100 | Loss 2.59894 | Win Count 21
# Epoch 0120/2100 | Loss 2.84396 | Win Count 22
# Epoch 0121/2100 | Loss 3.30111 | Win Count 22
# Epoch 0122/2100 | Loss 3.19198 | Win Count 23
# Epoch 0123/2100 | Loss 2.25832 | Win Count 24
# Epoch 0124/2100 | Loss 2.95974 | Win Count 25
# Epoch 0125/2100 | Loss 2.49022 | Win Count 25
# Epoch 0126/2100 | Loss 2.51446 | Win Count 25
# Epoch 0127/2100 | Loss 3.01182 | Win Count 25
# Epoch 0128/2100 | Loss 2.53798 | Win Count 26
# Epoch 0129/2100 | Loss 1.96667 | Win Count 26
# Epoch 0130/2100 | Loss 2.07269 | Win Count 27
# Epoch 0131/2100 | Loss 2.20260 | Win Count 27
# Epoch 0132/2100 | Loss 2.41620 | Win Count 28
# Epoch 0133/2100 | Loss 1.89070 | Win Count 28
# Epoch 0134/2100 | Loss 2.23771 | Win Count 29
# Epoch 0135/2100 | Loss 2.38446 | Win Count 29
# Epoch 0136/2100 | Loss 2.19264 | Win Count 30
# Epoch 0137/2100 | Loss 1.85142 | Win Count 30
# Epoch 0138/2100 | Loss 1.24246 | Win Count 31
# Epoch 0139/2100 | Loss 2.10123 | Win Count 31
# Epoch 0140/2100 | Loss 1.89088 | Win Count 32
# Epoch 0141/2100 | Loss 1.74683 | Win Count 32
# Epoch 0142/2100 | Loss 1.85273 | Win Count 32
# Epoch 0143/2100 | Loss 1.52778 | Win Count 32
# Epoch 0144/2100 | Loss 1.91485 | Win Count 32
# Epoch 0145/2100 | Loss 1.39239 | Win Count 32
# Epoch 0146/2100 | Loss 2.16145 | Win Count 32
# Epoch 0147/2100 | Loss 1.32334 | Win Count 32
# Epoch 0148/2100 | Loss 1.29181 | Win Count 33
# Epoch 0149/2100 | Loss 1.15656 | Win Count 34
# Epoch 0150/2100 | Loss 1.32227 | Win Count 34
# Epoch 0151/2100 | Loss 1.34462 | Win Count 34
# Epoch 0152/2100 | Loss 1.15530 | Win Count 35
# Epoch 0153/2100 | Loss 1.22455 | Win Count 35
# Epoch 0154/2100 | Loss 0.92925 | Win Count 36
# Epoch 0155/2100 | Loss 1.17063 | Win Count 36
# Epoch 0156/2100 | Loss 1.44046 | Win Count 37
# Epoch 0157/2100 | Loss 1.33517 | Win Count 38
# Epoch 0158/2100 | Loss 1.10182 | Win Count 39
# Epoch 0159/2100 | Loss 1.19025 | Win Count 39
# Epoch 0160/2100 | Loss 1.01496 | Win Count 39
# Epoch 0161/2100 | Loss 1.09882 | Win Count 40
# Epoch 0162/2100 | Loss 0.83213 | Win Count 41
# Epoch 0163/2100 | Loss 0.91758 | Win Count 42
# Epoch 0164/2100 | Loss 1.14545 | Win Count 42
# Epoch 0165/2100 | Loss 1.20309 | Win Count 43
# Epoch 0166/2100 | Loss 0.88774 | Win Count 44
# Epoch 0167/2100 | Loss 1.12336 | Win Count 44
# Epoch 0168/2100 | Loss 0.95882 | Win Count 45
# Epoch 0169/2100 | Loss 0.78478 | Win Count 45
# Epoch 0170/2100 | Loss 0.49102 | Win Count 45
# Epoch 0171/2100 | Loss 0.79398 | Win Count 46
# Epoch 0172/2100 | Loss 0.63614 | Win Count 46
# Epoch 0173/2100 | Loss 0.57306 | Win Count 46
# Epoch 0174/2100 | Loss 0.47509 | Win Count 46
# Epoch 0175/2100 | Loss 0.79505 | Win Count 46
# Epoch 0176/2100 | Loss 0.49630 | Win Count 46
# Epoch 0177/2100 | Loss 0.71399 | Win Count 46
# Epoch 0178/2100 | Loss 0.54812 | Win Count 46
# Epoch 0179/2100 | Loss 0.56517 | Win Count 47
# Epoch 0180/2100 | Loss 0.60990 | Win Count 48
# Epoch 0181/2100 | Loss 0.63587 | Win Count 48
# Epoch 0182/2100 | Loss 0.64260 | Win Count 49
# Epoch 0183/2100 | Loss 0.47501 | Win Count 50
# Epoch 0184/2100 | Loss 0.41015 | Win Count 51
# Epoch 0185/2100 | Loss 0.44626 | Win Count 51
# Epoch 0186/2100 | Loss 0.54461 | Win Count 52
# Epoch 0187/2100 | Loss 0.52279 | Win Count 52
# Epoch 0188/2100 | Loss 0.51399 | Win Count 52
# Epoch 0189/2100 | Loss 0.42597 | Win Count 53
# Epoch 0190/2100 | Loss 0.45327 | Win Count 53
# Epoch 0191/2100 | Loss 0.55181 | Win Count 53
# Epoch 0192/2100 | Loss 0.51915 | Win Count 54
# Epoch 0193/2100 | Loss 0.43856 | Win Count 54
# Epoch 0194/2100 | Loss 0.42911 | Win Count 55
# Epoch 0195/2100 | Loss 0.43535 | Win Count 55
# Epoch 0196/2100 | Loss 0.33726 | Win Count 56
# Epoch 0197/2100 | Loss 0.45311 | Win Count 57
# Epoch 0198/2100 | Loss 0.40242 | Win Count 58
# Epoch 0199/2100 | Loss 0.43050 | Win Count 58
# Epoch 0200/2100 | Loss 0.44102 | Win Count 58
# Epoch 0201/2100 | Loss 0.39864 | Win Count 59
# Epoch 0202/2100 | Loss 0.51764 | Win Count 60
# Epoch 0203/2100 | Loss 0.26024 | Win Count 60
# Epoch 0204/2100 | Loss 0.25821 | Win Count 61
# Epoch 0205/2100 | Loss 0.38707 | Win Count 62
# Epoch 0206/2100 | Loss 0.28716 | Win Count 62
# Epoch 0207/2100 | Loss 0.36036 | Win Count 63
# Epoch 0208/2100 | Loss 0.32702 | Win Count 63
# Epoch 0209/2100 | Loss 0.41793 | Win Count 63
# Epoch 0210/2100 | Loss 0.40227 | Win Count 64
# Epoch 0211/2100 | Loss 0.34283 | Win Count 64
# Epoch 0212/2100 | Loss 0.24157 | Win Count 65
# Epoch 0213/2100 | Loss 0.36873 | Win Count 66
# Epoch 0214/2100 | Loss 0.39668 | Win Count 67
# Epoch 0215/2100 | Loss 0.32794 | Win Count 67
# Epoch 0216/2100 | Loss 0.36229 | Win Count 67
# Epoch 0217/2100 | Loss 0.27459 | Win Count 67
# Epoch 0218/2100 | Loss 0.33137 | Win Count 68
# Epoch 0219/2100 | Loss 0.37778 | Win Count 69
# Epoch 0220/2100 | Loss 0.27930 | Win Count 69
# Epoch 0221/2100 | Loss 0.32696 | Win Count 70
# Epoch 0222/2100 | Loss 0.29378 | Win Count 71
# Epoch 0223/2100 | Loss 0.40164 | Win Count 71
# Epoch 0224/2100 | Loss 0.27416 | Win Count 72
# Epoch 0225/2100 | Loss 0.27755 | Win Count 72
# Epoch 0226/2100 | Loss 0.26229 | Win Count 72
# Epoch 0227/2100 | Loss 0.23976 | Win Count 73
# Epoch 0228/2100 | Loss 0.22099 | Win Count 73
# Epoch 0229/2100 | Loss 0.31673 | Win Count 74
# Epoch 0230/2100 | Loss 0.23375 | Win Count 74
# Epoch 0231/2100 | Loss 0.34317 | Win Count 75
# Epoch 0232/2100 | Loss 0.32378 | Win Count 76
# Epoch 0233/2100 | Loss 0.31576 | Win Count 76
# Epoch 0234/2100 | Loss 0.31154 | Win Count 77
# Epoch 0235/2100 | Loss 0.30687 | Win Count 77
# Epoch 0236/2100 | Loss 0.38246 | Win Count 77
# Epoch 0237/2100 | Loss 0.26179 | Win Count 77
# Epoch 0238/2100 | Loss 0.23910 | Win Count 77
# Epoch 0239/2100 | Loss 0.20299 | Win Count 78
# Epoch 0240/2100 | Loss 0.27078 | Win Count 79
# Epoch 0241/2100 | Loss 0.24920 | Win Count 80
# Epoch 0242/2100 | Loss 0.25894 | Win Count 80
# Epoch 0243/2100 | Loss 0.29518 | Win Count 80
# Epoch 0244/2100 | Loss 0.34627 | Win Count 81
# Epoch 0245/2100 | Loss 0.23352 | Win Count 81
# Epoch 0246/2100 | Loss 0.27880 | Win Count 81
# Epoch 0247/2100 | Loss 0.22933 | Win Count 81
# Epoch 0248/2100 | Loss 0.23071 | Win Count 82
# Epoch 0249/2100 | Loss 0.28351 | Win Count 83
# Epoch 0250/2100 | Loss 0.24163 | Win Count 83
# Epoch 0251/2100 | Loss 0.34597 | Win Count 83
# Epoch 0252/2100 | Loss 0.23155 | Win Count 84
# Epoch 0253/2100 | Loss 0.25249 | Win Count 85
# Epoch 0254/2100 | Loss 0.25258 | Win Count 85
# Epoch 0255/2100 | Loss 0.21457 | Win Count 85
# Epoch 0256/2100 | Loss 0.24044 | Win Count 85
# Epoch 0257/2100 | Loss 0.24596 | Win Count 86
# Epoch 0258/2100 | Loss 0.27123 | Win Count 87
# Epoch 0259/2100 | Loss 0.28804 | Win Count 88
# Epoch 0260/2100 | Loss 0.21017 | Win Count 88
# Epoch 0261/2100 | Loss 0.31679 | Win Count 89
# Epoch 0262/2100 | Loss 0.25873 | Win Count 90
# Epoch 0263/2100 | Loss 0.30138 | Win Count 91
# Epoch 0264/2100 | Loss 0.19213 | Win Count 91
# Epoch 0265/2100 | Loss 0.22339 | Win Count 91
# Epoch 0266/2100 | Loss 0.19315 | Win Count 91
# Epoch 0267/2100 | Loss 0.21296 | Win Count 91
# Epoch 0268/2100 | Loss 0.23598 | Win Count 92
# Epoch 0269/2100 | Loss 0.23941 | Win Count 92
# Epoch 0270/2100 | Loss 0.26945 | Win Count 92
# Epoch 0271/2100 | Loss 0.25958 | Win Count 93
# Epoch 0272/2100 | Loss 0.19459 | Win Count 94
# Epoch 0273/2100 | Loss 0.22485 | Win Count 95
# Epoch 0274/2100 | Loss 0.26666 | Win Count 95
# Epoch 0275/2100 | Loss 0.23066 | Win Count 96
# Epoch 0276/2100 | Loss 0.27803 | Win Count 97
# Epoch 0277/2100 | Loss 0.18596 | Win Count 97
# Epoch 0278/2100 | Loss 0.21036 | Win Count 98
# Epoch 0279/2100 | Loss 0.30134 | Win Count 99
# Epoch 0280/2100 | Loss 0.27166 | Win Count 99
# Epoch 0281/2100 | Loss 0.26957 | Win Count 99
# Epoch 0282/2100 | Loss 0.28140 | Win Count 99
# Epoch 0283/2100 | Loss 0.19395 | Win Count 100
# Epoch 0284/2100 | Loss 0.20218 | Win Count 100
# Epoch 0285/2100 | Loss 0.22150 | Win Count 100
# Epoch 0286/2100 | Loss 0.17256 | Win Count 101
# Epoch 0287/2100 | Loss 0.16727 | Win Count 102
# Epoch 0288/2100 | Loss 0.29580 | Win Count 102
# Epoch 0289/2100 | Loss 0.16315 | Win Count 103
# Epoch 0290/2100 | Loss 0.22531 | Win Count 104
# Epoch 0291/2100 | Loss 0.20848 | Win Count 105
# Epoch 0292/2100 | Loss 0.17389 | Win Count 105
# Epoch 0293/2100 | Loss 0.25154 | Win Count 105
# Epoch 0294/2100 | Loss 0.27309 | Win Count 105
# Epoch 0295/2100 | Loss 0.25821 | Win Count 105
# Epoch 0296/2100 | Loss 0.17209 | Win Count 106
# Epoch 0297/2100 | Loss 0.17505 | Win Count 106
# Epoch 0298/2100 | Loss 0.15466 | Win Count 107
# Epoch 0299/2100 | Loss 0.22371 | Win Count 108
# Epoch 0300/2100 | Loss 0.24061 | Win Count 108
# Epoch 0301/2100 | Loss 0.16675 | Win Count 109
# Epoch 0302/2100 | Loss 0.17461 | Win Count 109
# Epoch 0303/2100 | Loss 0.15591 | Win Count 109
# Epoch 0304/2100 | Loss 0.25921 | Win Count 109
# Epoch 0305/2100 | Loss 0.19677 | Win Count 110
# Epoch 0306/2100 | Loss 0.16954 | Win Count 110
# Epoch 0307/2100 | Loss 0.15947 | Win Count 110
# Epoch 0308/2100 | Loss 0.24756 | Win Count 111
# Epoch 0309/2100 | Loss 0.23458 | Win Count 112
# Epoch 0310/2100 | Loss 0.17921 | Win Count 112
# Epoch 0311/2100 | Loss 0.12196 | Win Count 113
# Epoch 0312/2100 | Loss 0.16799 | Win Count 113
# Epoch 0313/2100 | Loss 0.19619 | Win Count 114
# Epoch 0314/2100 | Loss 0.15071 | Win Count 115
# Epoch 0315/2100 | Loss 0.20306 | Win Count 116
# Epoch 0316/2100 | Loss 0.17202 | Win Count 116
# Epoch 0317/2100 | Loss 0.15258 | Win Count 117
# Epoch 0318/2100 | Loss 0.13058 | Win Count 117
# Epoch 0319/2100 | Loss 0.21157 | Win Count 118
# Epoch 0320/2100 | Loss 0.20844 | Win Count 118
# Epoch 0321/2100 | Loss 0.16057 | Win Count 118
# Epoch 0322/2100 | Loss 0.17312 | Win Count 118
# Epoch 0323/2100 | Loss 0.19134 | Win Count 119
# Epoch 0324/2100 | Loss 0.20826 | Win Count 119
# Epoch 0325/2100 | Loss 0.15834 | Win Count 119
# Epoch 0326/2100 | Loss 0.15389 | Win Count 120
# Epoch 0327/2100 | Loss 0.16639 | Win Count 120
# Epoch 0328/2100 | Loss 0.20814 | Win Count 121
# Epoch 0329/2100 | Loss 0.15276 | Win Count 122
# Epoch 0330/2100 | Loss 0.16356 | Win Count 122
# Epoch 0331/2100 | Loss 0.20007 | Win Count 122
# Epoch 0332/2100 | Loss 0.19131 | Win Count 123
# Epoch 0333/2100 | Loss 0.22255 | Win Count 124
# Epoch 0334/2100 | Loss 0.14781 | Win Count 124
# Epoch 0335/2100 | Loss 0.10999 | Win Count 125
# Epoch 0336/2100 | Loss 0.19447 | Win Count 126
# Epoch 0337/2100 | Loss 0.14264 | Win Count 127
# Epoch 0338/2100 | Loss 0.15221 | Win Count 127
# Epoch 0339/2100 | Loss 0.14642 | Win Count 128
# Epoch 0340/2100 | Loss 0.14486 | Win Count 129
# Epoch 0341/2100 | Loss 0.16527 | Win Count 129
# Epoch 0342/2100 | Loss 0.13563 | Win Count 129
# Epoch 0343/2100 | Loss 0.16393 | Win Count 129
# Epoch 0344/2100 | Loss 0.13747 | Win Count 130
# Epoch 0345/2100 | Loss 0.17133 | Win Count 131
# Epoch 0346/2100 | Loss 0.12190 | Win Count 132
# Epoch 0347/2100 | Loss 0.14211 | Win Count 132
# Epoch 0348/2100 | Loss 0.09044 | Win Count 133
# Epoch 0349/2100 | Loss 0.16114 | Win Count 133
# Epoch 0350/2100 | Loss 0.13386 | Win Count 134
# Epoch 0351/2100 | Loss 0.12555 | Win Count 135
# Epoch 0352/2100 | Loss 0.13195 | Win Count 135
# Epoch 0353/2100 | Loss 0.19468 | Win Count 136
# Epoch 0354/2100 | Loss 0.18193 | Win Count 136
# Epoch 0355/2100 | Loss 0.14222 | Win Count 136
# Epoch 0356/2100 | Loss 0.10882 | Win Count 137
# Epoch 0357/2100 | Loss 0.14680 | Win Count 138
# Epoch 0358/2100 | Loss 0.15295 | Win Count 139
# Epoch 0359/2100 | Loss 0.10375 | Win Count 140
# Epoch 0360/2100 | Loss 0.06858 | Win Count 140
# Epoch 0361/2100 | Loss 0.16479 | Win Count 141
# Epoch 0362/2100 | Loss 0.19521 | Win Count 142
# Epoch 0363/2100 | Loss 0.09449 | Win Count 142
# Epoch 0364/2100 | Loss 0.12417 | Win Count 142
# Epoch 0365/2100 | Loss 0.14360 | Win Count 142
# Epoch 0366/2100 | Loss 0.14775 | Win Count 142
# Epoch 0367/2100 | Loss 0.14241 | Win Count 143
# Epoch 0368/2100 | Loss 0.12344 | Win Count 143
# Epoch 0369/2100 | Loss 0.11763 | Win Count 144
# Epoch 0370/2100 | Loss 0.19050 | Win Count 144
# Epoch 0371/2100 | Loss 0.11003 | Win Count 145
# Epoch 0372/2100 | Loss 0.13802 | Win Count 145
# Epoch 0373/2100 | Loss 0.10694 | Win Count 146
# Epoch 0374/2100 | Loss 0.11087 | Win Count 146
# Epoch 0375/2100 | Loss 0.10626 | Win Count 146
# Epoch 0376/2100 | Loss 0.10140 | Win Count 146
# Epoch 0377/2100 | Loss 0.13725 | Win Count 147
# Epoch 0378/2100 | Loss 0.09000 | Win Count 148
# Epoch 0379/2100 | Loss 0.17829 | Win Count 148
# Epoch 0380/2100 | Loss 0.13170 | Win Count 149
# Epoch 0381/2100 | Loss 0.09168 | Win Count 149
# Epoch 0382/2100 | Loss 0.13837 | Win Count 150
# Epoch 0383/2100 | Loss 0.18307 | Win Count 151
# Epoch 0384/2100 | Loss 0.11842 | Win Count 152
# Epoch 0385/2100 | Loss 0.14967 | Win Count 152
# Epoch 0386/2100 | Loss 0.10217 | Win Count 152
# Epoch 0387/2100 | Loss 0.13422 | Win Count 153
# Epoch 0388/2100 | Loss 0.13185 | Win Count 154
# Epoch 0389/2100 | Loss 0.09657 | Win Count 154
# Epoch 0390/2100 | Loss 0.13922 | Win Count 154
# Epoch 0391/2100 | Loss 0.13371 | Win Count 155
# Epoch 0392/2100 | Loss 0.14055 | Win Count 156
# Epoch 0393/2100 | Loss 0.08741 | Win Count 157
# Epoch 0394/2100 | Loss 0.10931 | Win Count 158
# Epoch 0395/2100 | Loss 0.14860 | Win Count 158
# Epoch 0396/2100 | Loss 0.14455 | Win Count 158
# Epoch 0397/2100 | Loss 0.15033 | Win Count 158
# Epoch 0398/2100 | Loss 0.15588 | Win Count 159
# Epoch 0399/2100 | Loss 0.16337 | Win Count 160
# Epoch 0400/2100 | Loss 0.12116 | Win Count 161
# Epoch 0401/2100 | Loss 0.14556 | Win Count 162
# Epoch 0402/2100 | Loss 0.13381 | Win Count 163
# Epoch 0403/2100 | Loss 0.11388 | Win Count 163
# Epoch 0404/2100 | Loss 0.14058 | Win Count 163
# Epoch 0405/2100 | Loss 0.07496 | Win Count 164
# Epoch 0406/2100 | Loss 0.16123 | Win Count 165
# Epoch 0407/2100 | Loss 0.15913 | Win Count 166
# Epoch 0408/2100 | Loss 0.10179 | Win Count 167
# Epoch 0409/2100 | Loss 0.15334 | Win Count 168
# Epoch 0410/2100 | Loss 0.22462 | Win Count 168
# Epoch 0411/2100 | Loss 0.09839 | Win Count 169
# Epoch 0412/2100 | Loss 0.15575 | Win Count 170
# Epoch 0413/2100 | Loss 0.10089 | Win Count 171
# Epoch 0414/2100 | Loss 0.09248 | Win Count 172
# Epoch 0415/2100 | Loss 0.14489 | Win Count 173
# Epoch 0416/2100 | Loss 0.12232 | Win Count 174
# Epoch 0417/2100 | Loss 0.13088 | Win Count 175
# Epoch 0418/2100 | Loss 0.11847 | Win Count 176
# Epoch 0419/2100 | Loss 0.11788 | Win Count 176
# Epoch 0420/2100 | Loss 0.08898 | Win Count 176
# Epoch 0421/2100 | Loss 0.11108 | Win Count 177
# Epoch 0422/2100 | Loss 0.08312 | Win Count 178
# Epoch 0423/2100 | Loss 0.07053 | Win Count 179
# Epoch 0424/2100 | Loss 0.11340 | Win Count 179
# Epoch 0425/2100 | Loss 0.10021 | Win Count 180
# Epoch 0426/2100 | Loss 0.10352 | Win Count 181
# Epoch 0427/2100 | Loss 0.08419 | Win Count 181
# Epoch 0428/2100 | Loss 0.11997 | Win Count 182
# Epoch 0429/2100 | Loss 0.13859 | Win Count 182
# Epoch 0430/2100 | Loss 0.08435 | Win Count 183
# Epoch 0431/2100 | Loss 0.16198 | Win Count 184
# Epoch 0432/2100 | Loss 0.11411 | Win Count 184
# Epoch 0433/2100 | Loss 0.06563 | Win Count 184
# Epoch 0434/2100 | Loss 0.11250 | Win Count 185
# Epoch 0435/2100 | Loss 0.09079 | Win Count 186
# Epoch 0436/2100 | Loss 0.12539 | Win Count 186
# Epoch 0437/2100 | Loss 0.11070 | Win Count 187
# Epoch 0438/2100 | Loss 0.17280 | Win Count 188
# Epoch 0439/2100 | Loss 0.09314 | Win Count 189
# Epoch 0440/2100 | Loss 0.12208 | Win Count 190
# Epoch 0441/2100 | Loss 0.11233 | Win Count 190
# Epoch 0442/2100 | Loss 0.07637 | Win Count 190
# Epoch 0443/2100 | Loss 0.11734 | Win Count 191
# Epoch 0444/2100 | Loss 0.15914 | Win Count 191
# Epoch 0445/2100 | Loss 0.14201 | Win Count 192
# Epoch 0446/2100 | Loss 0.12407 | Win Count 192
# Epoch 0447/2100 | Loss 0.15587 | Win Count 192
# Epoch 0448/2100 | Loss 0.13424 | Win Count 192
# Epoch 0449/2100 | Loss 0.13026 | Win Count 193
# Epoch 0450/2100 | Loss 0.12424 | Win Count 194
# Epoch 0451/2100 | Loss 0.11710 | Win Count 195
# Epoch 0452/2100 | Loss 0.11312 | Win Count 196
# Epoch 0453/2100 | Loss 0.10685 | Win Count 197
# Epoch 0454/2100 | Loss 0.10450 | Win Count 198
# Epoch 0455/2100 | Loss 0.11631 | Win Count 198
# Epoch 0456/2100 | Loss 0.05600 | Win Count 199
# Epoch 0457/2100 | Loss 0.13262 | Win Count 199
# Epoch 0458/2100 | Loss 0.15918 | Win Count 200
# Epoch 0459/2100 | Loss 0.18571 | Win Count 200
# Epoch 0460/2100 | Loss 0.15498 | Win Count 201
# Epoch 0461/2100 | Loss 0.13062 | Win Count 201
# Epoch 0462/2100 | Loss 0.14709 | Win Count 202
# Epoch 0463/2100 | Loss 0.17471 | Win Count 202
# Epoch 0464/2100 | Loss 0.09753 | Win Count 202
# Epoch 0465/2100 | Loss 0.08103 | Win Count 202
# Epoch 0466/2100 | Loss 0.09958 | Win Count 202
# Epoch 0467/2100 | Loss 0.09720 | Win Count 203
# Epoch 0468/2100 | Loss 0.19657 | Win Count 204
# Epoch 0469/2100 | Loss 0.10937 | Win Count 205
# Epoch 0470/2100 | Loss 0.07563 | Win Count 206
# Epoch 0471/2100 | Loss 0.19705 | Win Count 207
# Epoch 0472/2100 | Loss 0.08648 | Win Count 208
# Epoch 0473/2100 | Loss 0.07996 | Win Count 209
# Epoch 0474/2100 | Loss 0.12681 | Win Count 209
# Epoch 0475/2100 | Loss 0.20375 | Win Count 210
# Epoch 0476/2100 | Loss 0.14321 | Win Count 210
# Epoch 0477/2100 | Loss 0.10719 | Win Count 211
# Epoch 0478/2100 | Loss 0.14299 | Win Count 211
# Epoch 0479/2100 | Loss 0.13006 | Win Count 212
# Epoch 0480/2100 | Loss 0.13204 | Win Count 213
# Epoch 0481/2100 | Loss 0.14692 | Win Count 214
# Epoch 0482/2100 | Loss 0.12724 | Win Count 215
# Epoch 0483/2100 | Loss 0.13151 | Win Count 216
# Epoch 0484/2100 | Loss 0.14568 | Win Count 216
# Epoch 0485/2100 | Loss 0.12868 | Win Count 217
# Epoch 0486/2100 | Loss 0.13054 | Win Count 218
# Epoch 0487/2100 | Loss 0.12084 | Win Count 218
# Epoch 0488/2100 | Loss 0.08991 | Win Count 219
# Epoch 0489/2100 | Loss 0.06683 | Win Count 220
# Epoch 0490/2100 | Loss 0.19928 | Win Count 221
# Epoch 0491/2100 | Loss 0.18227 | Win Count 221
# Epoch 0492/2100 | Loss 0.14678 | Win Count 221
# Epoch 0493/2100 | Loss 0.10953 | Win Count 222
# Epoch 0494/2100 | Loss 0.14701 | Win Count 222
# Epoch 0495/2100 | Loss 0.14687 | Win Count 223
# Epoch 0496/2100 | Loss 0.19068 | Win Count 224
# Epoch 0497/2100 | Loss 0.15532 | Win Count 225
# Epoch 0498/2100 | Loss 0.09064 | Win Count 225
# Epoch 0499/2100 | Loss 0.18644 | Win Count 226
# Epoch 0500/2100 | Loss 0.16927 | Win Count 227
# Epoch 0501/2100 | Loss 0.13089 | Win Count 227
# Epoch 0502/2100 | Loss 0.14128 | Win Count 227
# Epoch 0503/2100 | Loss 0.08909 | Win Count 227
# Epoch 0504/2100 | Loss 0.16215 | Win Count 227
# Epoch 0505/2100 | Loss 0.15951 | Win Count 228
# Epoch 0506/2100 | Loss 0.17961 | Win Count 228
# Epoch 0507/2100 | Loss 0.10537 | Win Count 229
# Epoch 0508/2100 | Loss 0.09039 | Win Count 230
# Epoch 0509/2100 | Loss 0.12392 | Win Count 231
# Epoch 0510/2100 | Loss 0.10084 | Win Count 232
# Epoch 0511/2100 | Loss 0.10878 | Win Count 233
# Epoch 0512/2100 | Loss 0.15617 | Win Count 233
# Epoch 0513/2100 | Loss 0.11738 | Win Count 234
# Epoch 0514/2100 | Loss 0.11751 | Win Count 234
# Epoch 0515/2100 | Loss 0.10961 | Win Count 235
# Epoch 0516/2100 | Loss 0.15312 | Win Count 236
# Epoch 0517/2100 | Loss 0.10103 | Win Count 237
# Epoch 0518/2100 | Loss 0.14398 | Win Count 237
# Epoch 0519/2100 | Loss 0.09966 | Win Count 238
# Epoch 0520/2100 | Loss 0.20163 | Win Count 238
# Epoch 0521/2100 | Loss 0.14643 | Win Count 238
# Epoch 0522/2100 | Loss 0.08784 | Win Count 238
# Epoch 0523/2100 | Loss 0.06665 | Win Count 238
# Epoch 0524/2100 | Loss 0.09994 | Win Count 238
# Epoch 0525/2100 | Loss 0.08686 | Win Count 238
# Epoch 0526/2100 | Loss 0.10368 | Win Count 239
# Epoch 0527/2100 | Loss 0.10620 | Win Count 240
# Epoch 0528/2100 | Loss 0.09218 | Win Count 240
# Epoch 0529/2100 | Loss 0.14093 | Win Count 241
# Epoch 0530/2100 | Loss 0.10494 | Win Count 242
# Epoch 0531/2100 | Loss 0.24352 | Win Count 243
# Epoch 0532/2100 | Loss 0.07746 | Win Count 244
# Epoch 0533/2100 | Loss 0.14771 | Win Count 245
# Epoch 0534/2100 | Loss 0.17713 | Win Count 245
# Epoch 0535/2100 | Loss 0.16569 | Win Count 245
# Epoch 0536/2100 | Loss 0.10324 | Win Count 246
# Epoch 0537/2100 | Loss 0.04509 | Win Count 246
# Epoch 0538/2100 | Loss 0.19515 | Win Count 246
# Epoch 0539/2100 | Loss 0.13672 | Win Count 247
# Epoch 0540/2100 | Loss 0.12824 | Win Count 247
# Epoch 0541/2100 | Loss 0.09893 | Win Count 248
# Epoch 0542/2100 | Loss 0.10611 | Win Count 249
# Epoch 0543/2100 | Loss 0.07411 | Win Count 250
# Epoch 0544/2100 | Loss 0.08267 | Win Count 250
# Epoch 0545/2100 | Loss 0.15411 | Win Count 251
# Epoch 0546/2100 | Loss 0.16023 | Win Count 251
# Epoch 0547/2100 | Loss 0.10988 | Win Count 251
# Epoch 0548/2100 | Loss 0.16564 | Win Count 251
# Epoch 0549/2100 | Loss 0.07261 | Win Count 252
# Epoch 0550/2100 | Loss 0.10414 | Win Count 253
# Epoch 0551/2100 | Loss 0.10663 | Win Count 254
# Epoch 0552/2100 | Loss 0.09496 | Win Count 255
# Epoch 0553/2100 | Loss 0.21392 | Win Count 256
# Epoch 0554/2100 | Loss 0.12484 | Win Count 256
# Epoch 0555/2100 | Loss 0.18388 | Win Count 257
# Epoch 0556/2100 | Loss 0.04001 | Win Count 258
# Epoch 0557/2100 | Loss 0.15920 | Win Count 258
# Epoch 0558/2100 | Loss 0.11430 | Win Count 259
# Epoch 0559/2100 | Loss 0.09690 | Win Count 259
# Epoch 0560/2100 | Loss 0.11352 | Win Count 259
# Epoch 0561/2100 | Loss 0.12225 | Win Count 259
# Epoch 0562/2100 | Loss 0.11348 | Win Count 260
# Epoch 0563/2100 | Loss 0.08924 | Win Count 260
# Epoch 0564/2100 | Loss 0.08930 | Win Count 260
# Epoch 0565/2100 | Loss 0.13532 | Win Count 260
# Epoch 0566/2100 | Loss 0.09516 | Win Count 260
# Epoch 0567/2100 | Loss 0.26007 | Win Count 260
# Epoch 0568/2100 | Loss 0.10478 | Win Count 261
# Epoch 0569/2100 | Loss 0.16517 | Win Count 262
# Epoch 0570/2100 | Loss 0.15782 | Win Count 263
# Epoch 0571/2100 | Loss 0.10582 | Win Count 263
# Epoch 0572/2100 | Loss 0.18716 | Win Count 264
# Epoch 0573/2100 | Loss 0.07954 | Win Count 265
# Epoch 0574/2100 | Loss 0.12834 | Win Count 265
# Epoch 0575/2100 | Loss 0.14301 | Win Count 266
# Epoch 0576/2100 | Loss 0.14249 | Win Count 266
# Epoch 0577/2100 | Loss 0.10578 | Win Count 267
# Epoch 0578/2100 | Loss 0.03347 | Win Count 268
# Epoch 0579/2100 | Loss 0.09884 | Win Count 269
# Epoch 0580/2100 | Loss 0.07171 | Win Count 270
# Epoch 0581/2100 | Loss 0.07686 | Win Count 271
# Epoch 0582/2100 | Loss 0.09489 | Win Count 272
# Epoch 0583/2100 | Loss 0.15558 | Win Count 273
# Epoch 0584/2100 | Loss 0.16341 | Win Count 274
# Epoch 0585/2100 | Loss 0.07229 | Win Count 274
# Epoch 0586/2100 | Loss 0.18127 | Win Count 275
# Epoch 0587/2100 | Loss 0.08201 | Win Count 276
# Epoch 0588/2100 | Loss 0.14285 | Win Count 277
# Epoch 0589/2100 | Loss 0.10194 | Win Count 278
# Epoch 0590/2100 | Loss 0.06698 | Win Count 279
# Epoch 0591/2100 | Loss 0.06639 | Win Count 280
# Epoch 0592/2100 | Loss 0.06815 | Win Count 280
# Epoch 0593/2100 | Loss 0.08217 | Win Count 281
# Epoch 0594/2100 | Loss 0.14383 | Win Count 281
# Epoch 0595/2100 | Loss 0.07039 | Win Count 281
# Epoch 0596/2100 | Loss 0.05823 | Win Count 282
# Epoch 0597/2100 | Loss 0.13067 | Win Count 283
# Epoch 0598/2100 | Loss 0.08321 | Win Count 284
# Epoch 0599/2100 | Loss 0.16258 | Win Count 284
# Epoch 0600/2100 | Loss 0.08749 | Win Count 285
# Epoch 0601/2100 | Loss 0.07577 | Win Count 285
# Epoch 0602/2100 | Loss 0.11318 | Win Count 286
# Epoch 0603/2100 | Loss 0.04965 | Win Count 286
# Epoch 0604/2100 | Loss 0.15901 | Win Count 287
# Epoch 0605/2100 | Loss 0.08407 | Win Count 288
# Epoch 0606/2100 | Loss 0.12605 | Win Count 289
# Epoch 0607/2100 | Loss 0.11664 | Win Count 290
# Epoch 0608/2100 | Loss 0.13113 | Win Count 291
# Epoch 0609/2100 | Loss 0.04343 | Win Count 291
# Epoch 0610/2100 | Loss 0.09997 | Win Count 292
# Epoch 0611/2100 | Loss 0.13679 | Win Count 292
# Epoch 0612/2100 | Loss 0.10998 | Win Count 292
# Epoch 0613/2100 | Loss 0.06530 | Win Count 293
# Epoch 0614/2100 | Loss 0.18682 | Win Count 293
# Epoch 0615/2100 | Loss 0.09987 | Win Count 293
# Epoch 0616/2100 | Loss 0.10720 | Win Count 294
# Epoch 0617/2100 | Loss 0.07892 | Win Count 294
# Epoch 0618/2100 | Loss 0.08472 | Win Count 295
# Epoch 0619/2100 | Loss 0.19228 | Win Count 295
# Epoch 0620/2100 | Loss 0.11708 | Win Count 296
# Epoch 0621/2100 | Loss 0.08512 | Win Count 297
# Epoch 0622/2100 | Loss 0.17238 | Win Count 297
# Epoch 0623/2100 | Loss 0.05874 | Win Count 297
# Epoch 0624/2100 | Loss 0.08703 | Win Count 298
# Epoch 0625/2100 | Loss 0.06791 | Win Count 298
# Epoch 0626/2100 | Loss 0.11755 | Win Count 299
# Epoch 0627/2100 | Loss 0.11846 | Win Count 300
# Epoch 0628/2100 | Loss 0.10889 | Win Count 301
# Epoch 0629/2100 | Loss 0.11921 | Win Count 302
# Epoch 0630/2100 | Loss 0.15473 | Win Count 302
# Epoch 0631/2100 | Loss 0.12630 | Win Count 303
# Epoch 0632/2100 | Loss 0.13420 | Win Count 304
# Epoch 0633/2100 | Loss 0.09405 | Win Count 304
# Epoch 0634/2100 | Loss 0.08689 | Win Count 304
# Epoch 0635/2100 | Loss 0.15132 | Win Count 304
# Epoch 0636/2100 | Loss 0.09833 | Win Count 305
# Epoch 0637/2100 | Loss 0.08834 | Win Count 306
# Epoch 0638/2100 | Loss 0.08777 | Win Count 306
# Epoch 0639/2100 | Loss 0.16391 | Win Count 307
# Epoch 0640/2100 | Loss 0.08069 | Win Count 307
# Epoch 0641/2100 | Loss 0.10845 | Win Count 307
# Epoch 0642/2100 | Loss 0.11942 | Win Count 307
# Epoch 0643/2100 | Loss 0.11606 | Win Count 307
# Epoch 0644/2100 | Loss 0.10685 | Win Count 308
# Epoch 0645/2100 | Loss 0.08387 | Win Count 309
# Epoch 0646/2100 | Loss 0.10448 | Win Count 309
# Epoch 0647/2100 | Loss 0.15810 | Win Count 309
# Epoch 0648/2100 | Loss 0.09947 | Win Count 310
# Epoch 0649/2100 | Loss 0.13726 | Win Count 310
# Epoch 0650/2100 | Loss 0.07658 | Win Count 311
# Epoch 0651/2100 | Loss 0.12739 | Win Count 312
# Epoch 0652/2100 | Loss 0.05200 | Win Count 312
# Epoch 0653/2100 | Loss 0.08429 | Win Count 312
# Epoch 0654/2100 | Loss 0.10345 | Win Count 312
# Epoch 0655/2100 | Loss 0.13516 | Win Count 313
# Epoch 0656/2100 | Loss 0.08706 | Win Count 313
# Epoch 0657/2100 | Loss 0.08137 | Win Count 314
# Epoch 0658/2100 | Loss 0.21426 | Win Count 314
# Epoch 0659/2100 | Loss 0.07976 | Win Count 314
# Epoch 0660/2100 | Loss 0.14137 | Win Count 314
# Epoch 0661/2100 | Loss 0.06743 | Win Count 315
# Epoch 0662/2100 | Loss 0.10521 | Win Count 316
# Epoch 0663/2100 | Loss 0.07417 | Win Count 316
# Epoch 0664/2100 | Loss 0.09444 | Win Count 317
# Epoch 0665/2100 | Loss 0.06854 | Win Count 318
# Epoch 0666/2100 | Loss 0.11939 | Win Count 319
# Epoch 0667/2100 | Loss 0.11381 | Win Count 320
# Epoch 0668/2100 | Loss 0.08144 | Win Count 320
# Epoch 0669/2100 | Loss 0.12967 | Win Count 320
# Epoch 0670/2100 | Loss 0.14964 | Win Count 321
# Epoch 0671/2100 | Loss 0.10868 | Win Count 321
# Epoch 0672/2100 | Loss 0.08182 | Win Count 321
# Epoch 0673/2100 | Loss 0.07416 | Win Count 322
# Epoch 0674/2100 | Loss 0.07802 | Win Count 323
# Epoch 0675/2100 | Loss 0.14591 | Win Count 324
# Epoch 0676/2100 | Loss 0.10604 | Win Count 325
# Epoch 0677/2100 | Loss 0.10075 | Win Count 325
# Epoch 0678/2100 | Loss 0.11540 | Win Count 325
# Epoch 0679/2100 | Loss 0.09042 | Win Count 325
# Epoch 0680/2100 | Loss 0.09623 | Win Count 325
# Epoch 0681/2100 | Loss 0.07845 | Win Count 326
# Epoch 0682/2100 | Loss 0.09297 | Win Count 327
# Epoch 0683/2100 | Loss 0.08390 | Win Count 327
# Epoch 0684/2100 | Loss 0.07730 | Win Count 328
# Epoch 0685/2100 | Loss 0.07832 | Win Count 329
# Epoch 0686/2100 | Loss 0.08711 | Win Count 329
# Epoch 0687/2100 | Loss 0.06949 | Win Count 329
# Epoch 0688/2100 | Loss 0.06453 | Win Count 329
# Epoch 0689/2100 | Loss 0.17155 | Win Count 329
# Epoch 0690/2100 | Loss 0.08404 | Win Count 329
# Epoch 0691/2100 | Loss 0.08128 | Win Count 329
# Epoch 0692/2100 | Loss 0.04863 | Win Count 330
# Epoch 0693/2100 | Loss 0.07880 | Win Count 330
# Epoch 0694/2100 | Loss 0.09594 | Win Count 330
# Epoch 0695/2100 | Loss 0.07811 | Win Count 330
# Epoch 0696/2100 | Loss 0.06112 | Win Count 330
# Epoch 0697/2100 | Loss 0.05185 | Win Count 331
# Epoch 0698/2100 | Loss 0.08160 | Win Count 332
# Epoch 0699/2100 | Loss 0.15684 | Win Count 333
# Epoch 0700/2100 | Loss 0.15254 | Win Count 334
# Epoch 0701/2100 | Loss 0.09510 | Win Count 335
# Epoch 0702/2100 | Loss 0.05012 | Win Count 335
# Epoch 0703/2100 | Loss 0.10195 | Win Count 336
# Epoch 0704/2100 | Loss 0.08545 | Win Count 337
# Epoch 0705/2100 | Loss 0.06952 | Win Count 338
# Epoch 0706/2100 | Loss 0.10671 | Win Count 339
# Epoch 0707/2100 | Loss 0.10630 | Win Count 339
# Epoch 0708/2100 | Loss 0.12967 | Win Count 340
# Epoch 0709/2100 | Loss 0.11228 | Win Count 341
# Epoch 0710/2100 | Loss 0.13750 | Win Count 341
# Epoch 0711/2100 | Loss 0.08852 | Win Count 342
# Epoch 0712/2100 | Loss 0.09032 | Win Count 342
# Epoch 0713/2100 | Loss 0.08022 | Win Count 343
# Epoch 0714/2100 | Loss 0.10564 | Win Count 343
# Epoch 0715/2100 | Loss 0.09311 | Win Count 344
# Epoch 0716/2100 | Loss 0.09283 | Win Count 345
# Epoch 0717/2100 | Loss 0.05874 | Win Count 346
# Epoch 0718/2100 | Loss 0.06874 | Win Count 346
# Epoch 0719/2100 | Loss 0.08891 | Win Count 347
# Epoch 0720/2100 | Loss 0.08614 | Win Count 348
# Epoch 0721/2100 | Loss 0.07234 | Win Count 348
# Epoch 0722/2100 | Loss 0.07369 | Win Count 349
# Epoch 0723/2100 | Loss 0.07161 | Win Count 350
# Epoch 0724/2100 | Loss 0.06918 | Win Count 351
# Epoch 0725/2100 | Loss 0.10394 | Win Count 352
# Epoch 0726/2100 | Loss 0.10530 | Win Count 353
# Epoch 0727/2100 | Loss 0.11526 | Win Count 354
# Epoch 0728/2100 | Loss 0.09315 | Win Count 354
# Epoch 0729/2100 | Loss 0.08052 | Win Count 355
# Epoch 0730/2100 | Loss 0.05792 | Win Count 356
# Epoch 0731/2100 | Loss 0.08608 | Win Count 357
# Epoch 0732/2100 | Loss 0.11489 | Win Count 357
# Epoch 0733/2100 | Loss 0.08815 | Win Count 357
# Epoch 0734/2100 | Loss 0.05781 | Win Count 357
# Epoch 0735/2100 | Loss 0.08035 | Win Count 358
# Epoch 0736/2100 | Loss 0.07070 | Win Count 359
# Epoch 0737/2100 | Loss 0.07615 | Win Count 360
# Epoch 0738/2100 | Loss 0.07692 | Win Count 361
# Epoch 0739/2100 | Loss 0.08058 | Win Count 361
# Epoch 0740/2100 | Loss 0.07270 | Win Count 362
# Epoch 0741/2100 | Loss 0.08604 | Win Count 362
# Epoch 0742/2100 | Loss 0.06668 | Win Count 362
# Epoch 0743/2100 | Loss 0.08349 | Win Count 363
# Epoch 0744/2100 | Loss 0.07551 | Win Count 363
# Epoch 0745/2100 | Loss 0.06255 | Win Count 364
# Epoch 0746/2100 | Loss 0.09553 | Win Count 365
# Epoch 0747/2100 | Loss 0.05718 | Win Count 366
# Epoch 0748/2100 | Loss 0.09339 | Win Count 366
# Epoch 0749/2100 | Loss 0.04194 | Win Count 367
# Epoch 0750/2100 | Loss 0.08053 | Win Count 368
# Epoch 0751/2100 | Loss 0.08452 | Win Count 368
# Epoch 0752/2100 | Loss 0.05618 | Win Count 368
# Epoch 0753/2100 | Loss 0.10981 | Win Count 368
# Epoch 0754/2100 | Loss 0.07680 | Win Count 369
# Epoch 0755/2100 | Loss 0.07530 | Win Count 370
# Epoch 0756/2100 | Loss 0.08008 | Win Count 371
# Epoch 0757/2100 | Loss 0.08703 | Win Count 371
# Epoch 0758/2100 | Loss 0.04866 | Win Count 372
# Epoch 0759/2100 | Loss 0.06617 | Win Count 373
# Epoch 0760/2100 | Loss 0.07913 | Win Count 374
# Epoch 0761/2100 | Loss 0.09715 | Win Count 374
# Epoch 0762/2100 | Loss 0.06776 | Win Count 375
# Epoch 0763/2100 | Loss 0.07248 | Win Count 376
# Epoch 0764/2100 | Loss 0.06075 | Win Count 376
# Epoch 0765/2100 | Loss 0.09228 | Win Count 377
# Epoch 0766/2100 | Loss 0.10252 | Win Count 378
# Epoch 0767/2100 | Loss 0.09469 | Win Count 379
# Epoch 0768/2100 | Loss 0.06042 | Win Count 379
# Epoch 0769/2100 | Loss 0.08656 | Win Count 379
# Epoch 0770/2100 | Loss 0.07460 | Win Count 380
# Epoch 0771/2100 | Loss 0.04686 | Win Count 381
# Epoch 0772/2100 | Loss 0.10122 | Win Count 382
# Epoch 0773/2100 | Loss 0.05030 | Win Count 383
# Epoch 0774/2100 | Loss 0.06479 | Win Count 383
# Epoch 0775/2100 | Loss 0.05848 | Win Count 384
# Epoch 0776/2100 | Loss 0.06558 | Win Count 385
# Epoch 0777/2100 | Loss 0.05824 | Win Count 385
# Epoch 0778/2100 | Loss 0.04562 | Win Count 385
# Epoch 0779/2100 | Loss 0.06791 | Win Count 385
# Epoch 0780/2100 | Loss 0.03384 | Win Count 386
# Epoch 0781/2100 | Loss 0.09721 | Win Count 386
# Epoch 0782/2100 | Loss 0.05920 | Win Count 387
# Epoch 0783/2100 | Loss 0.05965 | Win Count 388
# Epoch 0784/2100 | Loss 0.09969 | Win Count 389
# Epoch 0785/2100 | Loss 0.08446 | Win Count 390
# Epoch 0786/2100 | Loss 0.07304 | Win Count 391
# Epoch 0787/2100 | Loss 0.07645 | Win Count 391
# Epoch 0788/2100 | Loss 0.07702 | Win Count 392
# Epoch 0789/2100 | Loss 0.06751 | Win Count 393
# Epoch 0790/2100 | Loss 0.05613 | Win Count 394
# Epoch 0791/2100 | Loss 0.08586 | Win Count 395
# Epoch 0792/2100 | Loss 0.05509 | Win Count 396
# Epoch 0793/2100 | Loss 0.05276 | Win Count 397
# Epoch 0794/2100 | Loss 0.04289 | Win Count 398
# Epoch 0795/2100 | Loss 0.09608 | Win Count 399
# Epoch 0796/2100 | Loss 0.12138 | Win Count 399
# Epoch 0797/2100 | Loss 0.05664 | Win Count 399
# Epoch 0798/2100 | Loss 0.10572 | Win Count 399
# Epoch 0799/2100 | Loss 0.05720 | Win Count 399
# Epoch 0800/2100 | Loss 0.05880 | Win Count 400
# Epoch 0801/2100 | Loss 0.03808 | Win Count 400
# Epoch 0802/2100 | Loss 0.08534 | Win Count 400
# Epoch 0803/2100 | Loss 0.05080 | Win Count 401
# Epoch 0804/2100 | Loss 0.06056 | Win Count 401
# Epoch 0805/2100 | Loss 0.06427 | Win Count 402
# Epoch 0806/2100 | Loss 0.11609 | Win Count 402
# Epoch 0807/2100 | Loss 0.04804 | Win Count 403
# Epoch 0808/2100 | Loss 0.05452 | Win Count 404
# Epoch 0809/2100 | Loss 0.08018 | Win Count 404
# Epoch 0810/2100 | Loss 0.04546 | Win Count 405
# Epoch 0811/2100 | Loss 0.04669 | Win Count 405
# Epoch 0812/2100 | Loss 0.08979 | Win Count 406
# Epoch 0813/2100 | Loss 0.08092 | Win Count 407
# Epoch 0814/2100 | Loss 0.04662 | Win Count 408
# Epoch 0815/2100 | Loss 0.04934 | Win Count 409
# Epoch 0816/2100 | Loss 0.05953 | Win Count 410
# Epoch 0817/2100 | Loss 0.05464 | Win Count 410
# Epoch 0818/2100 | Loss 0.03830 | Win Count 411
# Epoch 0819/2100 | Loss 0.06496 | Win Count 412
# Epoch 0820/2100 | Loss 0.07485 | Win Count 413
# Epoch 0821/2100 | Loss 0.06560 | Win Count 414
# Epoch 0822/2100 | Loss 0.08110 | Win Count 414
# Epoch 0823/2100 | Loss 0.09257 | Win Count 415
# Epoch 0824/2100 | Loss 0.06492 | Win Count 416
# Epoch 0825/2100 | Loss 0.04439 | Win Count 417
# Epoch 0826/2100 | Loss 0.04761 | Win Count 417
# Epoch 0827/2100 | Loss 0.08302 | Win Count 417
# Epoch 0828/2100 | Loss 0.09979 | Win Count 417
# Epoch 0829/2100 | Loss 0.03432 | Win Count 417
# Epoch 0830/2100 | Loss 0.04871 | Win Count 417
# Epoch 0831/2100 | Loss 0.09055 | Win Count 417
# Epoch 0832/2100 | Loss 0.03138 | Win Count 418
# Epoch 0833/2100 | Loss 0.04690 | Win Count 419
# Epoch 0834/2100 | Loss 0.10551 | Win Count 420
# Epoch 0835/2100 | Loss 0.08064 | Win Count 421
# Epoch 0836/2100 | Loss 0.06419 | Win Count 422
# Epoch 0837/2100 | Loss 0.03190 | Win Count 423
# Epoch 0838/2100 | Loss 0.08450 | Win Count 424
# Epoch 0839/2100 | Loss 0.05874 | Win Count 425
# Epoch 0840/2100 | Loss 0.02863 | Win Count 426
# Epoch 0841/2100 | Loss 0.09820 | Win Count 426
# Epoch 0842/2100 | Loss 0.03738 | Win Count 427
# Epoch 0843/2100 | Loss 0.06594 | Win Count 428
# Epoch 0844/2100 | Loss 0.06873 | Win Count 429
# Epoch 0845/2100 | Loss 0.03320 | Win Count 430
# Epoch 0846/2100 | Loss 0.06916 | Win Count 431
# Epoch 0847/2100 | Loss 0.03789 | Win Count 432
# Epoch 0848/2100 | Loss 0.07414 | Win Count 433
# Epoch 0849/2100 | Loss 0.05458 | Win Count 434
# Epoch 0850/2100 | Loss 0.04818 | Win Count 435
# Epoch 0851/2100 | Loss 0.07617 | Win Count 435
# Epoch 0852/2100 | Loss 0.08022 | Win Count 436
# Epoch 0853/2100 | Loss 0.03889 | Win Count 437
# Epoch 0854/2100 | Loss 0.07544 | Win Count 437
# Epoch 0855/2100 | Loss 0.05381 | Win Count 437
# Epoch 0856/2100 | Loss 0.05915 | Win Count 438
# Epoch 0857/2100 | Loss 0.07055 | Win Count 438
# Epoch 0858/2100 | Loss 0.06248 | Win Count 439
# Epoch 0859/2100 | Loss 0.06565 | Win Count 440
# Epoch 0860/2100 | Loss 0.09535 | Win Count 440
# Epoch 0861/2100 | Loss 0.03773 | Win Count 440
# Epoch 0862/2100 | Loss 0.05525 | Win Count 440
# Epoch 0863/2100 | Loss 0.03589 | Win Count 441
# Epoch 0864/2100 | Loss 0.03691 | Win Count 442
# Epoch 0865/2100 | Loss 0.09101 | Win Count 442
# Epoch 0866/2100 | Loss 0.05737 | Win Count 442
# Epoch 0867/2100 | Loss 0.05364 | Win Count 443
# Epoch 0868/2100 | Loss 0.05227 | Win Count 444
# Epoch 0869/2100 | Loss 0.06619 | Win Count 445
# Epoch 0870/2100 | Loss 0.06067 | Win Count 446
# Epoch 0871/2100 | Loss 0.07067 | Win Count 446
# Epoch 0872/2100 | Loss 0.05042 | Win Count 447
# Epoch 0873/2100 | Loss 0.03822 | Win Count 448
# Epoch 0874/2100 | Loss 0.07479 | Win Count 448
# Epoch 0875/2100 | Loss 0.04660 | Win Count 448
# Epoch 0876/2100 | Loss 0.05885 | Win Count 449
# Epoch 0877/2100 | Loss 0.03962 | Win Count 450
# Epoch 0878/2100 | Loss 0.04766 | Win Count 451
# Epoch 0879/2100 | Loss 0.05049 | Win Count 452
# Epoch 0880/2100 | Loss 0.06463 | Win Count 453
# Epoch 0881/2100 | Loss 0.04421 | Win Count 454
# Epoch 0882/2100 | Loss 0.05095 | Win Count 455
# Epoch 0883/2100 | Loss 0.08516 | Win Count 455
# Epoch 0884/2100 | Loss 0.03955 | Win Count 456
# Epoch 0885/2100 | Loss 0.08265 | Win Count 456
# Epoch 0886/2100 | Loss 0.04133 | Win Count 457
# Epoch 0887/2100 | Loss 0.06333 | Win Count 457
# Epoch 0888/2100 | Loss 0.04703 | Win Count 458
# Epoch 0889/2100 | Loss 0.05355 | Win Count 458
# Epoch 0890/2100 | Loss 0.03974 | Win Count 459
# Epoch 0891/2100 | Loss 0.08331 | Win Count 460
# Epoch 0892/2100 | Loss 0.04998 | Win Count 460
# Epoch 0893/2100 | Loss 0.04186 | Win Count 460
# Epoch 0894/2100 | Loss 0.06350 | Win Count 461
# Epoch 0895/2100 | Loss 0.07575 | Win Count 461
# Epoch 0896/2100 | Loss 0.02956 | Win Count 462
# Epoch 0897/2100 | Loss 0.03392 | Win Count 463
# Epoch 0898/2100 | Loss 0.07536 | Win Count 463
# Epoch 0899/2100 | Loss 0.03347 | Win Count 463
# Epoch 0900/2100 | Loss 0.05410 | Win Count 464
# Epoch 0901/2100 | Loss 0.03590 | Win Count 464
# Epoch 0902/2100 | Loss 0.04514 | Win Count 465
# Epoch 0903/2100 | Loss 0.03098 | Win Count 466
# Epoch 0904/2100 | Loss 0.07824 | Win Count 466
# Epoch 0905/2100 | Loss 0.08329 | Win Count 467
# Epoch 0906/2100 | Loss 0.03511 | Win Count 467
# Epoch 0907/2100 | Loss 0.07006 | Win Count 467
# Epoch 0908/2100 | Loss 0.03450 | Win Count 468
# Epoch 0909/2100 | Loss 0.07568 | Win Count 468
# Epoch 0910/2100 | Loss 0.05235 | Win Count 469
# Epoch 0911/2100 | Loss 0.04524 | Win Count 470
# Epoch 0912/2100 | Loss 0.05341 | Win Count 471
# Epoch 0913/2100 | Loss 0.03309 | Win Count 472
# Epoch 0914/2100 | Loss 0.04305 | Win Count 473
# Epoch 0915/2100 | Loss 0.05192 | Win Count 474
# Epoch 0916/2100 | Loss 0.05524 | Win Count 474
# Epoch 0917/2100 | Loss 0.04929 | Win Count 475
# Epoch 0918/2100 | Loss 0.04198 | Win Count 476
# Epoch 0919/2100 | Loss 0.05157 | Win Count 476
# Epoch 0920/2100 | Loss 0.03970 | Win Count 477
# Epoch 0921/2100 | Loss 0.04196 | Win Count 478
# Epoch 0922/2100 | Loss 0.02965 | Win Count 479
# Epoch 0923/2100 | Loss 0.05498 | Win Count 479
# Epoch 0924/2100 | Loss 0.03739 | Win Count 480
# Epoch 0925/2100 | Loss 0.05608 | Win Count 480
# Epoch 0926/2100 | Loss 0.02976 | Win Count 480
# Epoch 0927/2100 | Loss 0.04049 | Win Count 481
# Epoch 0928/2100 | Loss 0.05453 | Win Count 482
# Epoch 0929/2100 | Loss 0.05830 | Win Count 483
# Epoch 0930/2100 | Loss 0.04457 | Win Count 484
# Epoch 0931/2100 | Loss 0.03785 | Win Count 485
# Epoch 0932/2100 | Loss 0.02901 | Win Count 486
# Epoch 0933/2100 | Loss 0.05383 | Win Count 487
# Epoch 0934/2100 | Loss 0.03671 | Win Count 488
# Epoch 0935/2100 | Loss 0.02621 | Win Count 489
# Epoch 0936/2100 | Loss 0.02778 | Win Count 490
# Epoch 0937/2100 | Loss 0.04458 | Win Count 490
# Epoch 0938/2100 | Loss 0.06360 | Win Count 491
# Epoch 0939/2100 | Loss 0.03687 | Win Count 492
# Epoch 0940/2100 | Loss 0.04513 | Win Count 493
# Epoch 0941/2100 | Loss 0.04436 | Win Count 494
# Epoch 0942/2100 | Loss 0.03560 | Win Count 495
# Epoch 0943/2100 | Loss 0.04750 | Win Count 496
# Epoch 0944/2100 | Loss 0.03451 | Win Count 497
# Epoch 0945/2100 | Loss 0.05546 | Win Count 498
# Epoch 0946/2100 | Loss 0.04272 | Win Count 498
# Epoch 0947/2100 | Loss 0.03632 | Win Count 498
# Epoch 0948/2100 | Loss 0.04580 | Win Count 499
# Epoch 0949/2100 | Loss 0.04645 | Win Count 499
# Epoch 0950/2100 | Loss 0.02881 | Win Count 499
# Epoch 0951/2100 | Loss 0.03584 | Win Count 499
# Epoch 0952/2100 | Loss 0.06481 | Win Count 500
# Epoch 0953/2100 | Loss 0.07187 | Win Count 500
# Epoch 0954/2100 | Loss 0.05565 | Win Count 501
# Epoch 0955/2100 | Loss 0.04611 | Win Count 502
# Epoch 0956/2100 | Loss 0.07310 | Win Count 502
# Epoch 0957/2100 | Loss 0.04829 | Win Count 503
# Epoch 0958/2100 | Loss 0.04477 | Win Count 504
# Epoch 0959/2100 | Loss 0.03901 | Win Count 505
# Epoch 0960/2100 | Loss 0.03096 | Win Count 506
# Epoch 0961/2100 | Loss 0.03840 | Win Count 507
# Epoch 0962/2100 | Loss 0.06307 | Win Count 508
# Epoch 0963/2100 | Loss 0.05278 | Win Count 509
# Epoch 0964/2100 | Loss 0.02490 | Win Count 510
# Epoch 0965/2100 | Loss 0.02492 | Win Count 511
# Epoch 0966/2100 | Loss 0.03907 | Win Count 512
# Epoch 0967/2100 | Loss 0.02659 | Win Count 513
# Epoch 0968/2100 | Loss 0.02849 | Win Count 513
# Epoch 0969/2100 | Loss 0.06515 | Win Count 514
# Epoch 0970/2100 | Loss 0.02241 | Win Count 515
# Epoch 0971/2100 | Loss 0.03134 | Win Count 516
# Epoch 0972/2100 | Loss 0.04932 | Win Count 517
# Epoch 0973/2100 | Loss 0.07923 | Win Count 517
# Epoch 0974/2100 | Loss 0.02335 | Win Count 518
# Epoch 0975/2100 | Loss 0.04980 | Win Count 519
# Epoch 0976/2100 | Loss 0.03198 | Win Count 520
# Epoch 0977/2100 | Loss 0.03695 | Win Count 521
# Epoch 0978/2100 | Loss 0.03521 | Win Count 522
# Epoch 0979/2100 | Loss 0.04093 | Win Count 523
# Epoch 0980/2100 | Loss 0.04541 | Win Count 524
# Epoch 0981/2100 | Loss 0.03466 | Win Count 524
# Epoch 0982/2100 | Loss 0.05135 | Win Count 525
# Epoch 0983/2100 | Loss 0.03434 | Win Count 526
# Epoch 0984/2100 | Loss 0.03558 | Win Count 527
# Epoch 0985/2100 | Loss 0.02751 | Win Count 527
# Epoch 0986/2100 | Loss 0.10240 | Win Count 527
# Epoch 0987/2100 | Loss 0.02636 | Win Count 528
# Epoch 0988/2100 | Loss 0.05198 | Win Count 529
# Epoch 0989/2100 | Loss 0.04586 | Win Count 530
# Epoch 0990/2100 | Loss 0.03660 | Win Count 531
# Epoch 0991/2100 | Loss 0.03508 | Win Count 532
# Epoch 0992/2100 | Loss 0.05579 | Win Count 532
# Epoch 0993/2100 | Loss 0.03218 | Win Count 533
# Epoch 0994/2100 | Loss 0.03426 | Win Count 533
# Epoch 0995/2100 | Loss 0.03829 | Win Count 534
# Epoch 0996/2100 | Loss 0.09652 | Win Count 535
# Epoch 0997/2100 | Loss 0.07029 | Win Count 536
# Epoch 0998/2100 | Loss 0.03435 | Win Count 537
# Epoch 0999/2100 | Loss 0.04018 | Win Count 538
# Epoch 1000/2100 | Loss 0.04668 | Win Count 539
# Epoch 1001/2100 | Loss 0.05632 | Win Count 540
# Epoch 1002/2100 | Loss 0.04628 | Win Count 541
# Epoch 1003/2100 | Loss 0.07239 | Win Count 541
# Epoch 1004/2100 | Loss 0.02774 | Win Count 542
# Epoch 1005/2100 | Loss 0.03453 | Win Count 543
# Epoch 1006/2100 | Loss 0.08313 | Win Count 544
# Epoch 1007/2100 | Loss 0.04667 | Win Count 545
# Epoch 1008/2100 | Loss 0.07983 | Win Count 546
# Epoch 1009/2100 | Loss 0.01993 | Win Count 547
# Epoch 1010/2100 | Loss 0.04611 | Win Count 548
# Epoch 1011/2100 | Loss 0.03508 | Win Count 549
# Epoch 1012/2100 | Loss 0.03385 | Win Count 549
# Epoch 1013/2100 | Loss 0.04024 | Win Count 549
# Epoch 1014/2100 | Loss 0.05128 | Win Count 549
# Epoch 1015/2100 | Loss 0.03492 | Win Count 549
# Epoch 1016/2100 | Loss 0.05653 | Win Count 549
# Epoch 1017/2100 | Loss 0.04730 | Win Count 550
# Epoch 1018/2100 | Loss 0.05455 | Win Count 550
# Epoch 1019/2100 | Loss 0.05440 | Win Count 551
# Epoch 1020/2100 | Loss 0.06322 | Win Count 551
# Epoch 1021/2100 | Loss 0.05830 | Win Count 552
# Epoch 1022/2100 | Loss 0.05161 | Win Count 552
# Epoch 1023/2100 | Loss 0.03880 | Win Count 553
# Epoch 1024/2100 | Loss 0.04103 | Win Count 554
# Epoch 1025/2100 | Loss 0.04258 | Win Count 555
# Epoch 1026/2100 | Loss 0.02770 | Win Count 556
# Epoch 1027/2100 | Loss 0.03998 | Win Count 557
# Epoch 1028/2100 | Loss 0.02500 | Win Count 558
# ...
# Epoch 1768/2100 | Loss 0.03225 | Win Count 1102
# Epoch 1769/2100 | Loss 0.02428 | Win Count 1103
# Epoch 1770/2100 | Loss 0.02717 | Win Count 1104
# Epoch 1771/2100 | Loss 0.01518 | Win Count 1105
# Epoch 1772/2100 | Loss 0.07195 | Win Count 1106
# Epoch 1773/2100 | Loss 0.01793 | Win Count 1107
# Epoch 1774/2100 | Loss 0.02827 | Win Count 1108
# Epoch 1775/2100 | Loss 0.01896 | Win Count 1109
# Epoch 1776/2100 | Loss 0.02373 | Win Count 1110
# Epoch 1777/2100 | Loss 0.02985 | Win Count 1111
# Epoch 1778/2100 | Loss 0.04025 | Win Count 1112
# Epoch 1779/2100 | Loss 0.03293 | Win Count 1113
# Epoch 1780/2100 | Loss 0.04308 | Win Count 1114
# Epoch 1781/2100 | Loss 0.01627 | Win Count 1114
# Epoch 1782/2100 | Loss 0.05661 | Win Count 1115
# Epoch 1783/2100 | Loss 0.04639 | Win Count 1116
# Epoch 1784/2100 | Loss 0.06466 | Win Count 1117
# Epoch 1785/2100 | Loss 0.04868 | Win Count 1118
# Epoch 1786/2100 | Loss 0.05350 | Win Count 1118
# Epoch 1787/2100 | Loss 0.02850 | Win Count 1119
# Epoch 1788/2100 | Loss 0.04995 | Win Count 1120
# Epoch 1789/2100 | Loss 0.09952 | Win Count 1121
# Epoch 1790/2100 | Loss 0.05876 | Win Count 1122
# Epoch 1791/2100 | Loss 0.03944 | Win Count 1123
# Epoch 1792/2100 | Loss 0.03567 | Win Count 1124
# Epoch 1793/2100 | Loss 0.04382 | Win Count 1125
# Epoch 1794/2100 | Loss 0.02673 | Win Count 1125
# Epoch 1795/2100 | Loss 0.03580 | Win Count 1126
# Epoch 1796/2100 | Loss 0.03851 | Win Count 1127
# Epoch 1797/2100 | Loss 0.04005 | Win Count 1128
# Epoch 1798/2100 | Loss 0.03002 | Win Count 1128
# Epoch 1799/2100 | Loss 0.02270 | Win Count 1129
# Epoch 1800/2100 | Loss 0.02409 | Win Count 1130
# Epoch 1801/2100 | Loss 0.04758 | Win Count 1131
# Epoch 1802/2100 | Loss 0.04024 | Win Count 1132
# Epoch 1803/2100 | Loss 0.04410 | Win Count 1133
# Epoch 1804/2100 | Loss 0.04058 | Win Count 1134
# Epoch 1805/2100 | Loss 0.02794 | Win Count 1134
# Epoch 1806/2100 | Loss 0.08159 | Win Count 1134
# Epoch 1807/2100 | Loss 0.06660 | Win Count 1135
# Epoch 1808/2100 | Loss 0.03412 | Win Count 1136
# Epoch 1809/2100 | Loss 0.02924 | Win Count 1136
# Epoch 1810/2100 | Loss 0.10841 | Win Count 1137
# Epoch 1811/2100 | Loss 0.05149 | Win Count 1138
# Epoch 1812/2100 | Loss 0.05664 | Win Count 1138
# Epoch 1813/2100 | Loss 0.04884 | Win Count 1139
# Epoch 1814/2100 | Loss 0.07961 | Win Count 1140
# Epoch 1815/2100 | Loss 0.06976 | Win Count 1141
# Epoch 1816/2100 | Loss 0.03622 | Win Count 1141
# Epoch 1817/2100 | Loss 0.07916 | Win Count 1142
# Epoch 1818/2100 | Loss 0.05640 | Win Count 1143
# Epoch 1819/2100 | Loss 0.09197 | Win Count 1144
# Epoch 1820/2100 | Loss 0.07547 | Win Count 1144
# Epoch 1821/2100 | Loss 0.08171 | Win Count 1145
# Epoch 1822/2100 | Loss 0.04839 | Win Count 1146
# Epoch 1823/2100 | Loss 0.03694 | Win Count 1147
# Epoch 1824/2100 | Loss 0.08864 | Win Count 1147
# Epoch 1825/2100 | Loss 0.07172 | Win Count 1148
# Epoch 1826/2100 | Loss 0.04428 | Win Count 1149
# Epoch 1827/2100 | Loss 0.04537 | Win Count 1150
# Epoch 1828/2100 | Loss 0.04372 | Win Count 1151
# Epoch 1829/2100 | Loss 0.04031 | Win Count 1152
# Epoch 1830/2100 | Loss 0.02969 | Win Count 1153
# Epoch 1831/2100 | Loss 0.04225 | Win Count 1154
# Epoch 1832/2100 | Loss 0.04125 | Win Count 1155
# Epoch 1833/2100 | Loss 0.03155 | Win Count 1156
# Epoch 1834/2100 | Loss 0.05609 | Win Count 1157
# Epoch 1835/2100 | Loss 0.08371 | Win Count 1158
# Epoch 1836/2100 | Loss 0.03206 | Win Count 1158
# Epoch 1837/2100 | Loss 0.06591 | Win Count 1159
# Epoch 1838/2100 | Loss 0.02601 | Win Count 1160
# Epoch 1839/2100 | Loss 0.03759 | Win Count 1161
# Epoch 1840/2100 | Loss 0.06288 | Win Count 1162
# Epoch 1841/2100 | Loss 0.05309 | Win Count 1163
# Epoch 1842/2100 | Loss 0.03887 | Win Count 1164
# Epoch 1843/2100 | Loss 0.08732 | Win Count 1165
# Epoch 1844/2100 | Loss 0.03363 | Win Count 1166
# Epoch 1845/2100 | Loss 0.05968 | Win Count 1167
# Epoch 1846/2100 | Loss 0.04902 | Win Count 1167
# Epoch 1847/2100 | Loss 0.03396 | Win Count 1168
# Epoch 1848/2100 | Loss 0.04270 | Win Count 1168
# Epoch 1849/2100 | Loss 0.04823 | Win Count 1169
# Epoch 1850/2100 | Loss 0.05218 | Win Count 1170
# Epoch 1851/2100 | Loss 0.03975 | Win Count 1170
# Epoch 1852/2100 | Loss 0.05356 | Win Count 1170
# Epoch 1853/2100 | Loss 0.04856 | Win Count 1170
# Epoch 1854/2100 | Loss 0.10566 | Win Count 1171
# Epoch 1855/2100 | Loss 0.03979 | Win Count 1172
# Epoch 1856/2100 | Loss 0.02594 | Win Count 1173
# Epoch 1857/2100 | Loss 0.04184 | Win Count 1174
# Epoch 1858/2100 | Loss 0.02266 | Win Count 1174
# Epoch 1859/2100 | Loss 0.03094 | Win Count 1175
# Epoch 1860/2100 | Loss 0.04531 | Win Count 1176
# Epoch 1861/2100 | Loss 0.04864 | Win Count 1177
# Epoch 1862/2100 | Loss 0.03829 | Win Count 1178
# Epoch 1863/2100 | Loss 0.02450 | Win Count 1178
# Epoch 1864/2100 | Loss 0.05998 | Win Count 1179
# Epoch 1865/2100 | Loss 0.10889 | Win Count 1180
# Epoch 1866/2100 | Loss 0.02724 | Win Count 1181
# Epoch 1867/2100 | Loss 0.02558 | Win Count 1182
# Epoch 1868/2100 | Loss 0.05179 | Win Count 1183
# Epoch 1869/2100 | Loss 0.03338 | Win Count 1184
# Epoch 1870/2100 | Loss 0.06307 | Win Count 1185
# Epoch 1871/2100 | Loss 0.07551 | Win Count 1185
# Epoch 1872/2100 | Loss 0.05273 | Win Count 1185
# Epoch 1873/2100 | Loss 0.04518 | Win Count 1186
# Epoch 1874/2100 | Loss 0.06417 | Win Count 1187
# Epoch 1875/2100 | Loss 0.06060 | Win Count 1187
# Epoch 1876/2100 | Loss 0.04674 | Win Count 1188
# Epoch 1877/2100 | Loss 0.15407 | Win Count 1189
# Epoch 1878/2100 | Loss 0.06453 | Win Count 1190
# Epoch 1879/2100 | Loss 0.04804 | Win Count 1190
# Epoch 1880/2100 | Loss 0.05428 | Win Count 1191
# Epoch 1881/2100 | Loss 0.09135 | Win Count 1191
# Epoch 1882/2100 | Loss 0.04647 | Win Count 1192
# Epoch 1883/2100 | Loss 0.03685 | Win Count 1193
# Epoch 1884/2100 | Loss 0.03537 | Win Count 1194
# Epoch 1885/2100 | Loss 0.07583 | Win Count 1195
# Epoch 1886/2100 | Loss 0.10963 | Win Count 1196
# Epoch 1887/2100 | Loss 0.08503 | Win Count 1197
# Epoch 1888/2100 | Loss 0.05164 | Win Count 1197
# Epoch 1889/2100 | Loss 0.06913 | Win Count 1197
# Epoch 1890/2100 | Loss 0.05026 | Win Count 1197
# Epoch 1891/2100 | Loss 0.09807 | Win Count 1198
# Epoch 1892/2100 | Loss 0.07578 | Win Count 1199
# Epoch 1893/2100 | Loss 0.04031 | Win Count 1200
# Epoch 1894/2100 | Loss 0.06291 | Win Count 1201
# Epoch 1895/2100 | Loss 0.03149 | Win Count 1202
# Epoch 1896/2100 | Loss 0.02032 | Win Count 1203
# Epoch 1897/2100 | Loss 0.02771 | Win Count 1204
# Epoch 1898/2100 | Loss 0.10573 | Win Count 1204
# Epoch 1899/2100 | Loss 0.07673 | Win Count 1205
# Epoch 1900/2100 | Loss 0.04363 | Win Count 1205
# Epoch 1901/2100 | Loss 0.03116 | Win Count 1206
# Epoch 1902/2100 | Loss 0.03377 | Win Count 1207
# Epoch 1903/2100 | Loss 0.04819 | Win Count 1208
# Epoch 1904/2100 | Loss 0.05267 | Win Count 1209
# Epoch 1905/2100 | Loss 0.07768 | Win Count 1210
# Epoch 1906/2100 | Loss 0.10684 | Win Count 1211
# Epoch 1907/2100 | Loss 0.12976 | Win Count 1212
# Epoch 1908/2100 | Loss 0.07905 | Win Count 1212
# Epoch 1909/2100 | Loss 0.07840 | Win Count 1213
# Epoch 1910/2100 | Loss 0.04163 | Win Count 1213
# Epoch 1911/2100 | Loss 0.09550 | Win Count 1214
# Epoch 1912/2100 | Loss 0.03717 | Win Count 1214
# Epoch 1913/2100 | Loss 0.06042 | Win Count 1215
# Epoch 1914/2100 | Loss 0.09511 | Win Count 1216
# Epoch 1915/2100 | Loss 0.06779 | Win Count 1216
# Epoch 1916/2100 | Loss 0.05398 | Win Count 1217
# Epoch 1917/2100 | Loss 0.06318 | Win Count 1218
# Epoch 1918/2100 | Loss 0.03109 | Win Count 1219
# Epoch 1919/2100 | Loss 0.08768 | Win Count 1220
# Epoch 1920/2100 | Loss 0.10614 | Win Count 1221
# Epoch 1921/2100 | Loss 0.04856 | Win Count 1222
# Epoch 1922/2100 | Loss 0.09397 | Win Count 1223
# Epoch 1923/2100 | Loss 0.02833 | Win Count 1224
# Epoch 1924/2100 | Loss 0.03938 | Win Count 1224
# Epoch 1925/2100 | Loss 0.04527 | Win Count 1224
# Epoch 1926/2100 | Loss 0.07416 | Win Count 1225
# Epoch 1927/2100 | Loss 0.07919 | Win Count 1225
# Epoch 1928/2100 | Loss 0.07250 | Win Count 1226
# Epoch 1929/2100 | Loss 0.09914 | Win Count 1227
# Epoch 1930/2100 | Loss 0.06642 | Win Count 1228
# Epoch 1931/2100 | Loss 0.02749 | Win Count 1229
# Epoch 1932/2100 | Loss 0.04818 | Win Count 1230
# Epoch 1933/2100 | Loss 0.06673 | Win Count 1231
# Epoch 1934/2100 | Loss 0.03706 | Win Count 1231
# Epoch 1935/2100 | Loss 0.08797 | Win Count 1231
# Epoch 1936/2100 | Loss 0.03830 | Win Count 1232
# Epoch 1937/2100 | Loss 0.05316 | Win Count 1232
# Epoch 1938/2100 | Loss 0.03343 | Win Count 1232
# Epoch 1939/2100 | Loss 0.08175 | Win Count 1232
# Epoch 1940/2100 | Loss 0.05189 | Win Count 1233
# Epoch 1941/2100 | Loss 0.08098 | Win Count 1234
# Epoch 1942/2100 | Loss 0.03732 | Win Count 1235
# Epoch 1943/2100 | Loss 0.07957 | Win Count 1236
# Epoch 1944/2100 | Loss 0.04666 | Win Count 1237
# Epoch 1945/2100 | Loss 0.05734 | Win Count 1238
# Epoch 1946/2100 | Loss 0.03683 | Win Count 1239
# Epoch 1947/2100 | Loss 0.09644 | Win Count 1240
# Epoch 1948/2100 | Loss 0.05538 | Win Count 1240
# Epoch 1949/2100 | Loss 0.07452 | Win Count 1241
# Epoch 1950/2100 | Loss 0.05114 | Win Count 1242
# Epoch 1951/2100 | Loss 0.05921 | Win Count 1243
# Epoch 1952/2100 | Loss 0.05850 | Win Count 1243
# Epoch 1953/2100 | Loss 0.05040 | Win Count 1244
# Epoch 1954/2100 | Loss 0.06288 | Win Count 1245
# Epoch 1955/2100 | Loss 0.08616 | Win Count 1246
# Epoch 1956/2100 | Loss 0.05996 | Win Count 1246
# Epoch 1957/2100 | Loss 0.04943 | Win Count 1247
# Epoch 1958/2100 | Loss 0.05387 | Win Count 1248
# Epoch 1959/2100 | Loss 0.04358 | Win Count 1248
# Epoch 1960/2100 | Loss 0.03277 | Win Count 1249
# Epoch 1961/2100 | Loss 0.06238 | Win Count 1250
# Epoch 1962/2100 | Loss 0.04650 | Win Count 1251
# Epoch 1963/2100 | Loss 0.09863 | Win Count 1252
# Epoch 1964/2100 | Loss 0.09194 | Win Count 1252
# Epoch 1965/2100 | Loss 0.06156 | Win Count 1252
# Epoch 1966/2100 | Loss 0.04374 | Win Count 1253
# Epoch 1967/2100 | Loss 0.04663 | Win Count 1254
# Epoch 1968/2100 | Loss 0.03699 | Win Count 1255
# Epoch 1969/2100 | Loss 0.02342 | Win Count 1256
# Epoch 1970/2100 | Loss 0.06362 | Win Count 1256
# Epoch 1971/2100 | Loss 0.05859 | Win Count 1257
# Epoch 1972/2100 | Loss 0.11867 | Win Count 1258
# Epoch 1973/2100 | Loss 0.08830 | Win Count 1258
# Epoch 1974/2100 | Loss 0.03944 | Win Count 1259
# Epoch 1975/2100 | Loss 0.03296 | Win Count 1259
# Epoch 1976/2100 | Loss 0.04220 | Win Count 1260
# Epoch 1977/2100 | Loss 0.07054 | Win Count 1261
# Epoch 1978/2100 | Loss 0.03327 | Win Count 1262
# Epoch 1979/2100 | Loss 0.05179 | Win Count 1262
# Epoch 1980/2100 | Loss 0.05876 | Win Count 1263
# Epoch 1981/2100 | Loss 0.03944 | Win Count 1264
# Epoch 1982/2100 | Loss 0.03156 | Win Count 1265
# Epoch 1983/2100 | Loss 0.05136 | Win Count 1266
# Epoch 1984/2100 | Loss 0.05182 | Win Count 1267
# Epoch 1985/2100 | Loss 0.05068 | Win Count 1267
# Epoch 1986/2100 | Loss 0.05712 | Win Count 1267
# Epoch 1987/2100 | Loss 0.05275 | Win Count 1268
# Epoch 1988/2100 | Loss 0.04984 | Win Count 1269
# Epoch 1989/2100 | Loss 0.04426 | Win Count 1269
# Epoch 1990/2100 | Loss 0.07447 | Win Count 1270
# Epoch 1991/2100 | Loss 0.05878 | Win Count 1271
# Epoch 1992/2100 | Loss 0.07569 | Win Count 1272
# Epoch 1993/2100 | Loss 0.05132 | Win Count 1273
# Epoch 1994/2100 | Loss 0.05124 | Win Count 1274
# Epoch 1995/2100 | Loss 0.04999 | Win Count 1275
# Epoch 1996/2100 | Loss 0.06284 | Win Count 1275
# Epoch 1997/2100 | Loss 0.04630 | Win Count 1276
# Epoch 1998/2100 | Loss 0.05989 | Win Count 1277
# Epoch 1999/2100 | Loss 0.03906 | Win Count 1277
# Epoch 2000/2100 | Loss 0.06430 | Win Count 1278
# Epoch 2001/2100 | Loss 0.06439 | Win Count 1279
# Epoch 2002/2100 | Loss 0.09376 | Win Count 1280
# Epoch 2003/2100 | Loss 0.07656 | Win Count 1280
# Epoch 2004/2100 | Loss 0.08694 | Win Count 1281
# Epoch 2005/2100 | Loss 0.05555 | Win Count 1282
# Epoch 2006/2100 | Loss 0.03048 | Win Count 1282
# Epoch 2007/2100 | Loss 0.07035 | Win Count 1283
# Epoch 2008/2100 | Loss 0.03794 | Win Count 1284
# Epoch 2009/2100 | Loss 0.03438 | Win Count 1285
# Epoch 2010/2100 | Loss 0.04098 | Win Count 1285
# Epoch 2011/2100 | Loss 0.03845 | Win Count 1285
# Epoch 2012/2100 | Loss 0.06925 | Win Count 1286
# Epoch 2013/2100 | Loss 0.04031 | Win Count 1286
# Epoch 2014/2100 | Loss 0.07913 | Win Count 1287
# Epoch 2015/2100 | Loss 0.08465 | Win Count 1287
# Epoch 2016/2100 | Loss 0.03194 | Win Count 1288
# Epoch 2017/2100 | Loss 0.03898 | Win Count 1289
# Epoch 2018/2100 | Loss 0.06950 | Win Count 1290
# Epoch 2019/2100 | Loss 0.03094 | Win Count 1291
# Epoch 2020/2100 | Loss 0.03641 | Win Count 1292
# Epoch 2021/2100 | Loss 0.04378 | Win Count 1293
# Epoch 2022/2100 | Loss 0.04298 | Win Count 1294
# Epoch 2023/2100 | Loss 0.05443 | Win Count 1295
# Epoch 2024/2100 | Loss 0.04000 | Win Count 1296
# Epoch 2025/2100 | Loss 0.03034 | Win Count 1297
# Epoch 2026/2100 | Loss 0.04677 | Win Count 1298
# Epoch 2027/2100 | Loss 0.03866 | Win Count 1299
# Epoch 2028/2100 | Loss 0.07320 | Win Count 1299
# Epoch 2029/2100 | Loss 0.04218 | Win Count 1300
# Epoch 2030/2100 | Loss 0.10156 | Win Count 1301
# Epoch 2031/2100 | Loss 0.03947 | Win Count 1301
# Epoch 2032/2100 | Loss 0.04308 | Win Count 1302
# Epoch 2033/2100 | Loss 0.05525 | Win Count 1303
# Epoch 2034/2100 | Loss 0.03602 | Win Count 1304
# Epoch 2035/2100 | Loss 0.02826 | Win Count 1304
# Epoch 2036/2100 | Loss 0.04528 | Win Count 1305
# Epoch 2037/2100 | Loss 0.05962 | Win Count 1306
# Epoch 2038/2100 | Loss 0.03138 | Win Count 1307
# Epoch 2039/2100 | Loss 0.04515 | Win Count 1308
# Epoch 2040/2100 | Loss 0.06011 | Win Count 1309
# Epoch 2041/2100 | Loss 0.04351 | Win Count 1309
# Epoch 2042/2100 | Loss 0.03764 | Win Count 1310
# Epoch 2043/2100 | Loss 0.08205 | Win Count 1311
# Epoch 2044/2100 | Loss 0.04309 | Win Count 1312
# Epoch 2045/2100 | Loss 0.03417 | Win Count 1312
# Epoch 2046/2100 | Loss 0.03513 | Win Count 1313
# Epoch 2047/2100 | Loss 0.02870 | Win Count 1314
# Epoch 2048/2100 | Loss 0.04207 | Win Count 1315
# Epoch 2049/2100 | Loss 0.01782 | Win Count 1315
# Epoch 2050/2100 | Loss 0.03443 | Win Count 1315
# Epoch 2051/2100 | Loss 0.03072 | Win Count 1316
# Epoch 2052/2100 | Loss 0.02864 | Win Count 1317
# Epoch 2053/2100 | Loss 0.02520 | Win Count 1318
# Epoch 2054/2100 | Loss 0.08382 | Win Count 1318
# Epoch 2055/2100 | Loss 0.05177 | Win Count 1319
# Epoch 2056/2100 | Loss 0.06069 | Win Count 1320
# Epoch 2057/2100 | Loss 0.04652 | Win Count 1321
# Epoch 2058/2100 | Loss 0.04673 | Win Count 1322
# Epoch 2059/2100 | Loss 0.05409 | Win Count 1323
# Epoch 2060/2100 | Loss 0.04962 | Win Count 1324
# Epoch 2061/2100 | Loss 0.03877 | Win Count 1324
# Epoch 2062/2100 | Loss 0.03914 | Win Count 1325
# Epoch 2063/2100 | Loss 0.04530 | Win Count 1325
# Epoch 2064/2100 | Loss 0.02804 | Win Count 1326
# Epoch 2065/2100 | Loss 0.05020 | Win Count 1327
# Epoch 2066/2100 | Loss 0.04973 | Win Count 1328
# Epoch 2067/2100 | Loss 0.03065 | Win Count 1329
# Epoch 2068/2100 | Loss 0.02253 | Win Count 1329
# Epoch 2069/2100 | Loss 0.06581 | Win Count 1330
# Epoch 2070/2100 | Loss 0.05073 | Win Count 1330
# Epoch 2071/2100 | Loss 0.03171 | Win Count 1331
# Epoch 2072/2100 | Loss 0.03846 | Win Count 1332
# Epoch 2073/2100 | Loss 0.06741 | Win Count 1332
# Epoch 2074/2100 | Loss 0.06033 | Win Count 1333
# Epoch 2075/2100 | Loss 0.02650 | Win Count 1334
# Epoch 2076/2100 | Loss 0.04038 | Win Count 1334
# Epoch 2077/2100 | Loss 0.04166 | Win Count 1335
# Epoch 2078/2100 | Loss 0.05027 | Win Count 1336
# Epoch 2079/2100 | Loss 0.03075 | Win Count 1337
# Epoch 2080/2100 | Loss 0.01771 | Win Count 1338
# Epoch 2081/2100 | Loss 0.03798 | Win Count 1339
# Epoch 2082/2100 | Loss 0.03411 | Win Count 1339
# Epoch 2083/2100 | Loss 0.03379 | Win Count 1340
# Epoch 2084/2100 | Loss 0.05075 | Win Count 1340
# Epoch 2085/2100 | Loss 0.03692 | Win Count 1341
# Epoch 2086/2100 | Loss 0.02351 | Win Count 1341
# Epoch 2087/2100 | Loss 0.02756 | Win Count 1342
# Epoch 2088/2100 | Loss 0.02247 | Win Count 1343
# Epoch 2089/2100 | Loss 0.07292 | Win Count 1344
# Epoch 2090/2100 | Loss 0.04052 | Win Count 1344
# Epoch 2091/2100 | Loss 0.04129 | Win Count 1345
# Epoch 2092/2100 | Loss 0.01964 | Win Count 1346
# Epoch 2093/2100 | Loss 0.03147 | Win Count 1347
# Epoch 2094/2100 | Loss 0.04112 | Win Count 1348
# Epoch 2095/2100 | Loss 0.03226 | Win Count 1349
# Epoch 2096/2100 | Loss 0.03728 | Win Count 1350
# Epoch 2097/2100 | Loss 0.02993 | Win Count 1351
# Epoch 2098/2100 | Loss 0.04609 | Win Count 1351
# Epoch 2099/2100 | Loss 0.05945 | Win Count 1352
# Epoch 2100/2100 | Loss 0.04926 | Win Count 1353

# %%
num_games, num_wins = 0,0
for i in range(100):
    game.reset()
    a_0 = 1
    x_t, r_0, game_over = game.step(a_0)
    s_t = preprocess_images(x_t)
    game_over = False
    while not game_over:
        s_tml = s_t
        q = model.predict(s_t)[0]
        a_t = np.argmax(q)
        x_t, r_t, game_over = game.step(a_t)
        s_t = preprocess_images(x_t)
        if r_t == 1:
            num_wins += 1
    num_games += 1
    print("Game: {:03d}, Wins: {:03d}".format(num_games,num_wins), end="\n")
# Out:
# Game: 001, Wins: 001
# Game: 002, Wins: 002
# Game: 003, Wins: 002
# Game: 004, Wins: 003
# Game: 005, Wins: 003
# Game: 006, Wins: 003
# Game: 007, Wins: 003
# Game: 008, Wins: 003
# Game: 009, Wins: 004
# Game: 010, Wins: 004
# Game: 011, Wins: 005
# Game: 012, Wins: 006

# %%
model.load_weights("model_weight_tenis.HDF5")
